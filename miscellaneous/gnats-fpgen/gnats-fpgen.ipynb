# %%
from paraatm.io.iff import read_iff_file
data = read_iff_file('IFF_SFO+ASDEX_20190511_080104_86221.csv')

# %%
data
# Out:
#          recType                time  fltKey  bcnCode  cid    Source msgType  \
# 0              3 2019-05-11 07:26:57   26612   2270.0  NaN  0/MODE_S   0xE02
# 1              3 2019-05-11 07:26:58   26612   2270.0  NaN  0/MODE_S   0xE02
# 2              3 2019-05-11 07:27:00   26612   2270.0  NaN  0/MODE_S   0xE02
# 3              3 2019-05-11 07:27:01   26612   2270.0  NaN  0/MODE_S   0xE02
# 4              3 2019-05-11 07:27:02   26612   2270.0  NaN  0/MODE_S   0xE02
# ...          ...                 ...     ...      ...  ...       ...     ...
# 1030405        3 2019-05-12 07:53:49   33054      NaN  NaN     0/SFO   0xE02
# 1030406        3 2019-05-12 07:53:50   33054      NaN  NaN     0/SFO   0xE02
# 1030407        3 2019-05-12 07:53:51   33054      NaN  NaN     0/SFO   0xE02
# 1030408        3 2019-05-12 07:53:52   33054      NaN  NaN     0/SFO   0xE02
# 1030409        3 2019-05-12 07:53:53   33054      NaN  NaN     0/SFO   0xE02
#
# ...

# %%
import sys
sys.path.append('$HOME/NATS_Standalone_Ubuntu_16.04_Prod1.0/GNATS_Standalone')
sys.path.append('$HOME/NATS_Standalone_Ubuntu_16.04_Prod1.0/GNATS_Standalone/sample')

from FlightPlanSelector import FlightPlanSelector
# Out:
# !!!!!!!!!!!!!!!!!!
# Notice
# Some GNATS samples use Google map for presentation.  It requires Google map API key.  The key may exceed the maximum quota due to enormous NATS users' activities.
# If you experience Google map failure, please edit PathVisualizer.py with a new Google map key obtained from developers.google.com/maps/documentation/javascript/get-api-key
# !!!!!!!!!!!!!!!!!!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-e7b97db89779> in <module>
#       3 sys.path.append('$HOME/NATS_Standalone_Ubuntu_16.04_Prod1.0/GNATS_Standalone/sample')
#       4
# ----> 5 from FlightPlanSelector import FlightPlanSelector
#
# ~/para-atm-collection/miscellaneous/gnats-fpgen/FlightPlanSelector.py in <module>
#      15 #     The program takes different flight plan types and executes corresponding calculation.
#      16
# ...
