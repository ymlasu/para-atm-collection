# %% [markdown]
# # My First Jupyter Notebook
# This demonstration illustrates something important. The assumptions are that we have data from <a>www.github.com.
# ## A 2nd Heading ]
# '''
# code = code
# '''
#
#
# ## Important Module

# %%
print('This is my first Jupyter notebook line!')
# Out:
# This is my first Jupyter notebook line!

# %%
import numpy as np
# Out:
# ----------------------------------------------------------
# ModuleNotFoundError      Traceback (most recent call last)
# <ipython-input-2-0aa0b027fcb6> in <module>
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import pandas as pd
# Out:
# ----------------------------------------------------------
# ModuleNotFoundError      Traceback (most recent call last)
# <ipython-input-3-7dd3504c366f> in <module>
# ----> 1 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'
