# %% [markdown]
# # Bayesian Neural Networks to Predict Hard Landing with DASHlink Data
# Authors: Dr. Yingxiao Kong, Vanderbilt University
#
# Email: yingxiao.kong@vanderbit.edu

# %% [markdown]
# ## Overview of Research
# In this work, we use an open-source dataset - [NASA's DASHlink data](https://c3.ndc.nasa.gov/dashlink/) - to isolate data for landing aircraft that both have hard landing and normal landing occurrences. The objective is to use [this sample data](https://c3.ndc.nasa.gov/dashlink/projects/85/resources/?type=ds) to train a Bayesian Neural Network model to predict touchdown vertical speed for a landing aircraft with the intent to use as a screening for identifying hard landing events before they occur.
#
# This series of Jupyter notebook demonstrations into 3 modules. The presented module is in **bold**:
# - Module 1 - Download DASHlink Data
# - **Module 2 - DASHlink Data Pre-Processing and Feature Selection with Maximum Relevance and Minimum Reduandancy (mRMR)**
# - Module 3 - Bayesian Neural Network Model Training

# %% [markdown]
# ## Module 2: DASHlink Data Pre-Processing and Parameter Selection
# This is a demonstration of how to filter, standardize, and clean the DASHlink data downloaded and viewed in Module 1. In addition, we select the features most relevant to hard landing event.

# %% [markdown]
# ## Installing the required Python packages
#
# The required Python packages for this module are:
# - ***```pandas```***
# - ***```numpy```***
# - ***```scipy```***
# - ***```matplotlib```***

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Step 1: Isolate Data Landing at MSP
#
# ### Step 1a: Get all downloaded ```.mat``` files

# %%
import glob
OUTPUT_DIRECTORY = r'../../../dashlink-data'
downloaded_mat_files = glob.glob(OUTPUT_DIRECTORY+'/**/*.mat',recursive=True)
downloaded_mat_files
# Out:
# ['../../../dashlink-data/Tail_687_8/687200312261442.mat',
#  '../../../dashlink-data/Tail_687_8/687200403210418.mat',
#  '../../../dashlink-data/Tail_687_8/687200312300437.mat',
#  '../../../dashlink-data/Tail_687_8/687200309090752.mat',
#  '../../../dashlink-data/Tail_687_8/687200403162255.mat',
#  '../../../dashlink-data/Tail_687_8/687200403191335.mat',
#  '../../../dashlink-data/Tail_687_8/687200311301726.mat',
#  '../../../dashlink-data/Tail_687_8/687200402021225.mat',
#  '../../../dashlink-data/Tail_687_8/687200312241558.mat',
#  '../../../dashlink-data/Tail_687_8/687200401281006.mat',
#  '../../../dashlink-data/Tail_687_8/687200312180425.mat',
#  '../../../dashlink-data/Tail_687_8/687200402081856.mat',
#  '../../../dashlink-data/Tail_687_8/687200403211154.mat',
#  '../../../dashlink-data/Tail_687_8/687200403130700.mat',
#  '../../../dashlink-data/Tail_687_8/687200310291853.mat',
#  '../../../dashlink-data/Tail_687_8/687200402010708.mat',
#  '../../../dashlink-data/Tail_687_8/687200309111920.mat',
#  '../../../dashlink-data/Tail_687_8/687200401251440.mat',
#  '../../../dashlink-data/Tail_687_8/687200309141804.mat',
#  '../../../dashlink-data/Tail_687_8/687200310301410.mat',
#  '../../../dashlink-data/Tail_687_8/687200401281803.mat',
#  '../../../dashlink-data/Tail_687_8/687200312231200.mat',
#  '../../../dashlink-data/Tail_687_8/687200403171300.mat',
#  '../../../dashlink-data/Tail_687_8/687200403100532.mat',
#  '../../../dashlink-data/Tail_687_8/687200311140644.mat',
#  '../../../dashlink-data/Tail_687_8/687200309111040.mat',
#  '../../../dashlink-data/Tail_687_8/687200403071506.mat',
#  '../../../dashlink-data/Tail_687_8/687200403091734.mat',
#  '../../../dashlink-data/Tail_687_8/687200311091916.mat',
#  '../../../dashlink-data/Tail_687_8/687200402091359.mat',
#  '../../../dashlink-data/Tail_687_8/687200402261852.mat',
#  '../../../dashlink-data/Tail_687_8/687200312021109.mat',
#  '../../../dashlink-data/Tail_687_8/687200311110847.mat',
#  '../../../dashlink-data/Tail_687_8/687200312050639.mat',
#  '../../../dashlink-data/Tail_687_8/687200401250913.mat',
#  '../../../dashlink-data/Tail_687_8/687200402290636.mat',
#  '../../../dashlink-data/Tail_687_8/687200312221705.mat',
#  '../../../dashlink-data/Tail_687_8/687200311080607.mat',
#  '../../../dashlink-data/Tail_687_8/687200312311214.mat',
#  '../../../dashlink-data/Tail_687_8/687200402090406.mat',
#  '../../../dashlink-data/Tail_687_8/687200311040434.mat',
#  '../../../dashlink-data/Tail_687_8/687200403211538.mat',
#  '../../../dashlink-data/Tail_687_8/687200312291858.mat',
#  '../../../dashlink-data/Tail_687_8/687200311151533.mat',
#  '../../../dashlink-data/Tail_687_8/687200403111954.mat',
#  '../../../dashlink-data/Tail_687_8/687200312312210.mat',
#  '../../../dashlink-data/Tail_687_8/687200311071403.mat',
#  '../../../dashlink-data/Tail_687_8/687200402031129.mat',
#  '../../../dashlink-data/Tail_687_8/687200401021415.mat',
#  '../../../dashlink-data/Tail_687_8/687200401021138.mat',
#  '../../../dashlink-data/Tail_687_8/687200311161415.mat',
#  '../../../dashlink-data/Tail_687_8/687200312280746.mat',
#  '../../../dashlink-data/Tail_687_8/687200309141353.mat',
#  '../../../dashlink-data/Tail_687_8/687200312231439.mat',
#  '../../../dashlink-data/Tail_687_8/687200402120740.mat',
#  '../../../dashlink-data/Tail_687_8/687200401260631.mat',
#  '../../../dashlink-data/Tail_687_8/687200312281106.mat',
#  '../../../dashlink-data/Tail_687_8/687200403141657.mat',
#  '../../../dashlink-data/Tail_687_8/687200310311905.mat',
#  '../../../dashlink-data/Tail_687_8/687200312290904.mat',
#  '../../../dashlink-data/Tail_687_8/687200312031529.mat',
#  '../../../dashlink-data/Tail_687_8/687200311132152.mat',
#  '../../../dashlink-data/Tail_687_8/687200311161729.mat',
#  '../../../dashlink-data/Tail_687_8/687200401311027.mat',
#  '../../../dashlink-data/Tail_687_8/687200403050909.mat',
#  '../../../dashlink-data/Tail_687_8/687200403141520.mat',
#  '../../../dashlink-data/Tail_687_8/687200309081712.mat',
#  '../../../dashlink-data/Tail_687_8/687200311171711.mat',
#  '../../../dashlink-data/Tail_687_8/687200403041039.mat',
#  '../../../dashlink-data/Tail_687_8/687200312031932.mat',
#  '../../../dashlink-data/Tail_687_8/687200403240719.mat',
#  '../../../dashlink-data/Tail_687_8/687200403181142.mat',
#  '../../../dashlink-data/Tail_687_8/687200403210751.mat',
#  '../../../dashlink-data/Tail_687_8/687200310311240.mat',
#  '../../../dashlink-data/Tail_687_8/687200401291450.mat',
#  '../../../dashlink-data/Tail_687_8/687200403110729.mat',
#  '../../../dashlink-data/Tail_687_8/687200312190506.mat',
#  '../../../dashlink-data/Tail_687_8/687200402261151.mat',
#  '../../../dashlink-data/Tail_687_8/687200403010437.mat',
#  '../../../dashlink-data/Tail_687_8/687200403250852.mat',
#  '../../../dashlink-data/Tail_687_8/687200312301351.mat',
#  '../../../dashlink-data/Tail_687_8/687200402281741.mat',
#  '../../../dashlink-data/Tail_687_8/687200312160925.mat',
#  '../../../dashlink-data/Tail_687_8/687200312220504.mat',
#  '../../../dashlink-data/Tail_687_8/687200311141755.mat',
#  '../../../dashlink-data/Tail_687_8/687200403040500.mat',
#  '../../../dashlink-data/Tail_687_8/687200402101623.mat',
#  '../../../dashlink-data/Tail_687_8/687200311170949.mat',
#  '../../../dashlink-data/Tail_687_8/687200312190740.mat',
#  '../../../dashlink-data/Tail_687_8/687200312261759.mat',
#  '../../../dashlink-data/Tail_687_8/687200403020432.mat',
#  '../../../dashlink-data/Tail_687_8/687200403041623.mat',
#  '../../../dashlink-data/Tail_687_8/687200402010636.mat',
#  '../../../dashlink-data/Tail_687_8/687200402091613.mat',
#  '../../../dashlink-data/Tail_687_8/687200403051308.mat',
#  '../../../dashlink-data/Tail_687_8/687200401270426.mat',
#  '../../../dashlink-data/Tail_687_8/687200312040506.mat',
#  '../../../dashlink-data/Tail_687_8/687200401281441.mat',
#  '../../../dashlink-data/Tail_687_8/687200311031226.mat',
#  '../../../dashlink-data/Tail_687_8/687200402090531.mat',
#  '../../../dashlink-data/Tail_687_8/687200312261225.mat',
#  '../../../dashlink-data/Tail_687_8/687200309072033.mat',
#  '../../../dashlink-data/Tail_687_8/687200312310905.mat',
#  '../../../dashlink-data/Tail_687_8/687200403141145.mat',
#  '../../../dashlink-data/Tail_687_8/687200311131233.mat',
#  '../../../dashlink-data/Tail_687_8/687200312041221.mat',
#  '../../../dashlink-data/Tail_687_8/687200311101710.mat',
#  '../../../dashlink-data/Tail_687_8/687200311260620.mat',
#  '../../../dashlink-data/Tail_687_8/687200311031423.mat',
#  '../../../dashlink-data/Tail_687_8/687200403120852.mat',
#  '../../../dashlink-data/Tail_687_8/687200402050554.mat',
#  '../../../dashlink-data/Tail_687_8/687200401271437.mat',
#  '../../../dashlink-data/Tail_687_8/687200311271530.mat',
#  '../../../dashlink-data/Tail_687_8/687200309101042.mat',
#  '../../../dashlink-data/Tail_687_8/687200401031803.mat',
#  '../../../dashlink-data/Tail_687_8/687200311290817.mat',
#  '../../../dashlink-data/Tail_687_8/687200309131353.mat',
#  '../../../dashlink-data/Tail_687_8/687200311140936.mat',
#  '../../../dashlink-data/Tail_687_8/687200309071150.mat',
#  '../../../dashlink-data/Tail_687_8/687200402270948.mat',
#  '../../../dashlink-data/Tail_687_8/687200402011601.mat',
#  '../../../dashlink-data/Tail_687_8/687200312240825.mat',
#  '../../../dashlink-data/Tail_687_8/687200403150855.mat',
#  '../../../dashlink-data/Tail_687_8/687200311160942.mat',
#  '../../../dashlink-data/Tail_687_8/687200402261501.mat',
#  '../../../dashlink-data/Tail_687_8/687200403021951.mat',
#  '../../../dashlink-data/Tail_687_8/687200403110534.mat',
#  '../../../dashlink-data/Tail_687_8/687200401030511.mat',
#  '../../../dashlink-data/Tail_687_8/687200402062115.mat',
#  '../../../dashlink-data/Tail_687_8/687200309101354.mat',
#  '../../../dashlink-data/Tail_687_8/687200401251734.mat',
#  '../../../dashlink-data/Tail_687_8/687200403021802.mat',
#  '../../../dashlink-data/Tail_687_8/687200311131712.mat',
#  '../../../dashlink-data/Tail_687_8/687200312271251.mat',
#  '../../../dashlink-data/Tail_687_8/687200403200910.mat',
#  '../../../dashlink-data/Tail_687_8/687200312271455.mat',
#  '../../../dashlink-data/Tail_687_8/687200403130935.mat',
#  '../../../dashlink-data/Tail_687_8/687200312221409.mat',
#  '../../../dashlink-data/Tail_687_8/687200309140843.mat',
#  '../../../dashlink-data/Tail_687_8/687200401011507.mat',
#  '../../../dashlink-data/Tail_687_8/687200312230906.mat',
#  '../../../dashlink-data/Tail_687_8/687200311010556.mat',
#  '../../../dashlink-data/Tail_687_8/687200403181727.mat',
#  '../../../dashlink-data/Tail_687_8/687200309082130.mat',
#  '../../../dashlink-data/Tail_687_8/687200403231321.mat',
#  '../../../dashlink-data/Tail_687_8/687200312011244.mat',
#  '../../../dashlink-data/Tail_687_8/687200402240630.mat',
#  '../../../dashlink-data/Tail_687_8/687200402122024.mat',
#  '../../../dashlink-data/Tail_687_8/687200312230612.mat',
#  '../../../dashlink-data/Tail_687_8/687200312242034.mat',
#  '../../../dashlink-data/Tail_687_8/687200310291053.mat',
#  '../../../dashlink-data/Tail_687_8/687200311091652.mat',
#  '../../../dashlink-data/Tail_687_8/687200311260100.mat',
#  '../../../dashlink-data/Tail_687_8/687200312250604.mat',
#  '../../../dashlink-data/Tail_687_8/687200311162152.mat',
#  '../../../dashlink-data/Tail_687_8/687200401021809.mat',
#  '../../../dashlink-data/Tail_687_8/687200402291735.mat',
#  '../../../dashlink-data/Tail_687_8/687200402031558.mat',
#  '../../../dashlink-data/Tail_687_8/687200310301736.mat',
#  '../../../dashlink-data/Tail_687_8/687200309110559.mat',
#  '../../../dashlink-data/Tail_687_8/687200311081244.mat',
#  '../../../dashlink-data/Tail_687_8/687200311260921.mat',
#  '../../../dashlink-data/Tail_687_8/687200309091404.mat',
#  '../../../dashlink-data/Tail_687_8/687200312021805.mat',
#  '../../../dashlink-data/Tail_687_8/687200402271207.mat',
#  '../../../dashlink-data/Tail_687_8/687200402090851.mat',
#  '../../../dashlink-data/Tail_687_8/687200401311451.mat',
#  '../../../dashlink-data/Tail_687_8/687200312011832.mat',
#  '../../../dashlink-data/Tail_687_8/687200311122221.mat',
#  '../../../dashlink-data/Tail_687_8/687200311090941.mat',
#  '../../../dashlink-data/Tail_687_8/687200312251637.mat',
#  '../../../dashlink-data/Tail_687_8/687200402250416.mat',
#  '../../../dashlink-data/Tail_687_8/687200309100552.mat',
#  '../../../dashlink-data/Tail_687_8/687200401300427.mat',
#  '../../../dashlink-data/Tail_687_8/687200311121559.mat',
#  '../../../dashlink-data/Tail_687_8/687200403250703.mat',
#  '../../../dashlink-data/Tail_687_8/687200311020915.mat',
#  '../../../dashlink-data/Tail_687_8/687200310301138.mat',
#  '../../../dashlink-data/Tail_687_8/687200310310846.mat',
#  '../../../dashlink-data/Tail_687_8/687200403160836.mat',
#  '../../../dashlink-data/Tail_687_8/687200310291630.mat',
#  '../../../dashlink-data/Tail_687_8/687200403211823.mat',
#  '../../../dashlink-data/Tail_687_8/687200311271815.mat',
#  '../../../dashlink-data/Tail_687_8/687200401301033.mat',
#  '../../../dashlink-data/Tail_687_8/687200403170947.mat',
#  '../../../dashlink-data/Tail_687_8/687200312220859.mat',
#  '../../../dashlink-data/Tail_687_8/687200403141321.mat',
#  '../../../dashlink-data/Tail_687_8/687200402060358.mat',
#  '../../../dashlink-data/Tail_687_8/687200403100915.mat',
#  '../../../dashlink-data/Tail_687_8/687200403151113.mat',
#  '../../../dashlink-data/Tail_687_8/687200311050748.mat',
#  '../../../dashlink-data/Tail_687_8/687200311070719.mat',
#  '../../../dashlink-data/Tail_687_8/687200403240306.mat',
#  '../../../dashlink-data/Tail_687_8/687200403241126.mat',
#  '../../../dashlink-data/Tail_687_8/687200311301836.mat',
#  '../../../dashlink-data/Tail_687_8/687200403130701_1.mat',
#  '../../../dashlink-data/Tail_687_8/687200403111655.mat',
#  '../../../dashlink-data/Tail_687_8/687200403102049.mat',
#  '../../../dashlink-data/Tail_687_8/687200403250442.mat',
#  '../../../dashlink-data/Tail_687_8/687200402101739.mat',
#  '../../../dashlink-data/Tail_687_8/687200403051108.mat',
#  '../../../dashlink-data/Tail_687_8/687200403202022.mat',
#  '../../../dashlink-data/Tail_687_8/687200401250338.mat',
#  '../../../dashlink-data/Tail_687_8/687200403101038.mat',
#  '../../../dashlink-data/Tail_687_8/687200311040025.mat',
#  '../../../dashlink-data/Tail_687_8/687200402271938.mat',
#  '../../../dashlink-data/Tail_687_8/687200309101901.mat',
#  '../../../dashlink-data/Tail_687_8/687200402110642.mat',
#  '../../../dashlink-data/Tail_687_8/687200402061318.mat',
#  '../../../dashlink-data/Tail_687_8/687200403120702.mat',
#  '../../../dashlink-data/Tail_687_8/687200312300957.mat',
#  '../../../dashlink-data/Tail_687_8/687200403121805.mat',
#  '../../../dashlink-data/Tail_687_8/687200403080709.mat',
#  '../../../dashlink-data/Tail_687_8/687200401270822.mat',
#  '../../../dashlink-data/Tail_687_8/687200311172007.mat',
#  '../../../dashlink-data/Tail_687_8/687200311111857.mat',
#  '../../../dashlink-data/Tail_687_8/687200403131100.mat',
#  '../../../dashlink-data/Tail_687_8/687200311172056.mat',
#  '../../../dashlink-data/Tail_687_8/687200402110414.mat',
#  '../../../dashlink-data/Tail_687_8/687200403180425.mat',
#  '../../../dashlink-data/Tail_687_8/687200311130636.mat',
#  '../../../dashlink-data/Tail_687_8/687200311062150.mat',
#  '../../../dashlink-data/Tail_687_8/687200402270332.mat',
#  '../../../dashlink-data/Tail_687_8/687200401020958.mat',
#  '../../../dashlink-data/Tail_687_8/687200311061045.mat',
#  '../../../dashlink-data/Tail_687_8/687200312281538.mat',
#  '../../../dashlink-data/Tail_687_8/687200402031437.mat',
#  '../../../dashlink-data/Tail_687_8/687200401290429.mat',
#  '../../../dashlink-data/Tail_687_8/687200312161156.mat',
#  '../../../dashlink-data/Tail_687_8/687200403190546.mat',
#  '../../../dashlink-data/Tail_687_8/687200402270720.mat',
#  '../../../dashlink-data/Tail_687_8/687200402071421.mat',
#  '../../../dashlink-data/Tail_687_8/687200401020600.mat',
#  '../../../dashlink-data/Tail_687_8/687200402070751.mat',
#  '../../../dashlink-data/Tail_687_8/687200312041444.mat',
#  '../../../dashlink-data/Tail_687_8/687200401031434.mat',
#  '../../../dashlink-data/Tail_687_8/687200401012114.mat',
#  '../../../dashlink-data/Tail_687_8/687200401250550.mat',
#  '../../../dashlink-data/Tail_687_8/687200311070804.mat',
#  '../../../dashlink-data/Tail_687_8/687200402091118.mat',
#  '../../../dashlink-data/Tail_687_8/687200403170339.mat',
#  '../../../dashlink-data/Tail_687_8/687200311060428.mat',
#  '../../../dashlink-data/Tail_687_8/687200312300633.mat',
#  '../../../dashlink-data/Tail_687_8/687200311032130.mat',
#  '../../../dashlink-data/Tail_687_8/687200311031851.mat',
#  '../../../dashlink-data/Tail_687_8/687200401010833.mat',
#  '../../../dashlink-data/Tail_687_8/687200402281319.mat',
#  '../../../dashlink-data/Tail_687_8/687200311170740.mat',
#  '../../../dashlink-data/Tail_687_8/687200402021224.mat',
#  '../../../dashlink-data/Tail_687_8/687200403040727.mat',
#  '../../../dashlink-data/Tail_687_8/687200311011713.mat',
#  '../../../dashlink-data/Tail_687_8/687200311090641.mat',
#  '../../../dashlink-data/Tail_687_8/687200402111131.mat',
#  '../../../dashlink-data/Tail_687_8/687200311171145.mat',
#  '../../../dashlink-data/Tail_687_8/687200402291608.mat',
#  '../../../dashlink-data/Tail_687_8/687200402260721.mat',
#  '../../../dashlink-data/Tail_687_8/687200403220543.mat',
#  '../../../dashlink-data/Tail_687_8/687200311110557.mat',
#  '../../../dashlink-data/Tail_687_8/687200402081112.mat',
#  '../../../dashlink-data/Tail_687_8/687200402041505.mat',
#  '../../../dashlink-data/Tail_687_8/687200311051550.mat',
#  '../../../dashlink-data/Tail_687_8/687200402011339.mat',
#  '../../../dashlink-data/Tail_687_8/687200311141129.mat',
#  '../../../dashlink-data/Tail_687_8/687200311111030.mat',
#  '../../../dashlink-data/Tail_687_8/687200402101339.mat',
#  '../../../dashlink-data/Tail_687_8/687200402251304.mat',
#  '../../../dashlink-data/Tail_687_8/687200403120604.mat',
#  '../../../dashlink-data/Tail_687_8/687200311102124.mat',
#  '../../../dashlink-data/Tail_687_8/687200403111146.mat',
#  '../../../dashlink-data/Tail_687_8/687200403211339.mat',
#  '../../../dashlink-data/Tail_687_8/687200310290545.mat',
#  '../../../dashlink-data/Tail_687_8/687200403021133.mat',
#  '../../../dashlink-data/Tail_687_8/687200402030843.mat',
#  '../../../dashlink-data/Tail_687_8/687200312281312.mat',
#  '../../../dashlink-data/Tail_687_8/687200311071540.mat',
#  '../../../dashlink-data/Tail_687_8/687200403230553.mat',
#  '../../../dashlink-data/Tail_687_8/687200312221759.mat',
#  '../../../dashlink-data/Tail_687_8/687200312031456.mat',
#  '../../../dashlink-data/Tail_687_8/687200311101052.mat',
#  '../../../dashlink-data/Tail_687_8/687200311062021.mat',
#  '../../../dashlink-data/Tail_687_8/687200403011644.mat',
#  '../../../dashlink-data/Tail_687_8/687200401260917.mat',
#  '../../../dashlink-data/Tail_687_8/687200311271309.mat',
#  '../../../dashlink-data/Tail_687_8/687200403131455.mat',
#  '../../../dashlink-data/Tail_687_8/687200312040950.mat',
#  '../../../dashlink-data/Tail_687_8/687200402040922.mat',
#  '../../../dashlink-data/Tail_687_8/687200402100936.mat',
#  '../../../dashlink-data/Tail_687_8/687200310291424.mat',
#  '../../../dashlink-data/Tail_687_8/687200311281535.mat',
#  '../../../dashlink-data/Tail_687_8/687200309121351.mat',
#  '../../../dashlink-data/Tail_687_8/687200312260954.mat',
#  '../../../dashlink-data/Tail_687_8/687200403171721.mat',
#  '../../../dashlink-data/Tail_687_8/687200403192007.mat',
#  '../../../dashlink-data/Tail_687_8/687200309080749.mat',
#  '../../../dashlink-data/Tail_687_8/687200401010614.mat',
#  '../../../dashlink-data/Tail_687_8/687200403110339.mat',
#  '../../../dashlink-data/Tail_687_8/687200311151712.mat',
#  '../../../dashlink-data/Tail_687_8/687200312301541.mat',
#  '../../../dashlink-data/Tail_687_8/687200309090548.mat',
#  '../../../dashlink-data/Tail_687_8/687200312162015.mat',
#  '../../../dashlink-data/Tail_687_8/687200311121024.mat',
#  '../../../dashlink-data/Tail_687_8/687200402260350.mat',
#  '../../../dashlink-data/Tail_687_8/687200312301824.mat',
#  '../../../dashlink-data/Tail_687_8/687200312262153.mat',
#  '../../../dashlink-data/Tail_687_8/687200311011021.mat',
#  '../../../dashlink-data/Tail_687_8/687200311101305.mat',
#  '../../../dashlink-data/Tail_687_8/687200402261308.mat',
#  '../../../dashlink-data/Tail_687_8/687200312220659.mat',
#  '../../../dashlink-data/Tail_687_8/687200312021253.mat',
#  '../../../dashlink-data/Tail_687_8/687200311081020.mat',
#  '../../../dashlink-data/Tail_687_8/687200403090742.mat',
#  '../../../dashlink-data/Tail_687_8/687200311172054.mat',
#  '../../../dashlink-data/Tail_687_8/687200401271210.mat',
#  '../../../dashlink-data/Tail_687_8/687200312012220.mat',
#  '../../../dashlink-data/Tail_687_8/687200311111409.mat',
#  '../../../dashlink-data/Tail_687_8/687200311301714.mat',
#  '../../../dashlink-data/Tail_687_8/687200309100814.mat',
#  '../../../dashlink-data/Tail_687_8/687200401310503.mat',
#  '../../../dashlink-data/Tail_687_8/687200402020525.mat',
#  '../../../dashlink-data/Tail_687_8/687200312270537.mat',
#  '../../../dashlink-data/Tail_687_8/687200403191534.mat',
#  '../../../dashlink-data/Tail_687_8/687200403011455.mat',
#  '../../../dashlink-data/Tail_687_8/687200403021431.mat',
#  '../../../dashlink-data/Tail_687_8/687200311101529.mat',
#  '../../../dashlink-data/Tail_687_8/687200403201124.mat',
#  '../../../dashlink-data/Tail_687_8/687200311040508.mat',
#  '../../../dashlink-data/Tail_687_8/687200311100803.mat',
#  '../../../dashlink-data/Tail_687_8/687200311261830.mat',
#  '../../../dashlink-data/Tail_687_8/687200311151121.mat',
#  '../../../dashlink-data/Tail_687_8/687200402090718.mat',
#  '../../../dashlink-data/Tail_687_8/687200402051443.mat',
#  '../../../dashlink-data/Tail_687_8/687200311172056_1.mat',
#  '../../../dashlink-data/Tail_687_8/687200402090820.mat',
#  '../../../dashlink-data/Tail_687_8/687200309091549.mat',
#  '../../../dashlink-data/Tail_687_8/687200311300533.mat',
#  '../../../dashlink-data/Tail_687_8/687200311121557.mat',
#  '../../../dashlink-data/Tail_687_8/687200311041719.mat',
#  '../../../dashlink-data/Tail_687_8/687200402070331.mat',
#  '../../../dashlink-data/Tail_687_8/687200312030745.mat',
#  '../../../dashlink-data/Tail_687_8/687200403041401.mat',
#  '../../../dashlink-data/Tail_687_8/687200311281305.mat',
#  '../../../dashlink-data/Tail_687_8/687200403020530.mat',
#  '../../../dashlink-data/Tail_687_8/687200310302123.mat',
#  '../../../dashlink-data/Tail_687_8/687200311141457.mat',
#  '../../../dashlink-data/Tail_687_8/687200403020431.mat',
#  '../../../dashlink-data/Tail_687_8/687200311062051.mat',
#  '../../../dashlink-data/Tail_687_8/687200402271606.mat',
#  '../../../dashlink-data/Tail_687_8/687200311091443.mat',
#  '../../../dashlink-data/Tail_687_8/687200311271110.mat',
#  '../../../dashlink-data/Tail_687_8/687200309141530.mat',
#  '../../../dashlink-data/Tail_687_8/687200311021846.mat',
#  '../../../dashlink-data/Tail_687_8/687200312311822.mat',
#  '../../../dashlink-data/Tail_687_8/687200401251255.mat',
#  '../../../dashlink-data/Tail_687_8/687200402121702.mat',
#  '../../../dashlink-data/Tail_687_8/687200403121036.mat',
#  '../../../dashlink-data/Tail_687_8/687200402060734.mat',
#  '../../../dashlink-data/Tail_687_8/687200311270918.mat',
#  '../../../dashlink-data/Tail_687_8/687200403020900.mat',
#  '../../../dashlink-data/Tail_687_8/687200309090535.mat',
#  '../../../dashlink-data/Tail_687_8/687200401280520.mat',
#  '../../../dashlink-data/Tail_687_8/687200402091744.mat',
#  '../../../dashlink-data/Tail_687_8/687200311150916.mat',
#  '../../../dashlink-data/Tail_687_8/687200309130812.mat',
#  '../../../dashlink-data/Tail_687_8/687200401020601_1.mat',
#  '../../../dashlink-data/Tail_687_8/687200403100336.mat',
#  '../../../dashlink-data/Tail_687_8/687200403160653.mat',
#  '../../../dashlink-data/Tail_687_8/687200309121042.mat',
#  '../../../dashlink-data/Tail_687_8/687200309071329.mat',
#  '../../../dashlink-data/Tail_687_8/687200312160532.mat',
#  '../../../dashlink-data/Tail_687_8/687200403220742.mat',
#  '../../../dashlink-data/Tail_687_8/687200312011101.mat',
#  '../../../dashlink-data/Tail_687_8/687200403140853.mat',
#  '../../../dashlink-data/Tail_687_8/687200311131355.mat',
#  '../../../dashlink-data/Tail_687_8/687200403240926.mat',
#  '../../../dashlink-data/Tail_687_8/687200403241624.mat',
#  '../../../dashlink-data/Tail_687_8/687200311300856.mat',
#  '../../../dashlink-data/Tail_687_8/687200402261748.mat',
#  '../../../dashlink-data/Tail_687_8/687200401261329.mat',
#  '../../../dashlink-data/Tail_687_8/687200403161652.mat',
#  '../../../dashlink-data/Tail_687_8/687200403050333.mat',
#  '../../../dashlink-data/Tail_687_8/687200401020601.mat',
#  '../../../dashlink-data/Tail_687_8/687200309131646.mat',
#  '../../../dashlink-data/Tail_687_8/687200311051120.mat',
#  '../../../dashlink-data/Tail_687_8/687200312011509.mat',
#  '../../../dashlink-data/Tail_687_8/687200310301549.mat',
#  '../../../dashlink-data/Tail_687_8/687200402241632.mat',
#  '../../../dashlink-data/Tail_687_8/687200311160905.mat',
#  '../../../dashlink-data/Tail_687_8/687200311021141.mat',
#  '../../../dashlink-data/Tail_687_8/687200310311027.mat',
#  '../../../dashlink-data/Tail_687_8/687200403030338.mat',
#  '../../../dashlink-data/Tail_687_8/687200402040443.mat',
#  '../../../dashlink-data/Tail_687_8/687200312051116.mat',
#  '../../../dashlink-data/Tail_687_8/687200311131534.mat',
#  '../../../dashlink-data/Tail_687_8/687200309121906.mat',
#  '../../../dashlink-data/Tail_687_8/687200403051711.mat',
#  '../../../dashlink-data/Tail_687_8/687200311080819.mat',
#  '../../../dashlink-data/Tail_687_8/687200311301316.mat',
#  '../../../dashlink-data/Tail_687_8/687200402110851.mat',
#  '../../../dashlink-data/Tail_687_8/687200402071319.mat',
#  '../../../dashlink-data/Tail_687_8/687200401311754.mat',
#  '../../../dashlink-data/Tail_687_8/687200312311432.mat',
#  '../../../dashlink-data/Tail_687_8/687200402042125.mat',
#  '../../../dashlink-data/Tail_687_8/687200309120552.mat',
#  '../../../dashlink-data/Tail_687_8/687200402121311.mat',
#  '../../../dashlink-data/Tail_687_8/687200402261638.mat',
#  '../../../dashlink-data/Tail_687_8/687200312051307.mat',
#  '../../../dashlink-data/Tail_687_8/687200401311307.mat',
#  '../../../dashlink-data/Tail_687_8/687200402061703.mat',
#  '../../../dashlink-data/Tail_687_8/687200403231114.mat',
#  '../../../dashlink-data/Tail_687_8/687200311040433.mat',
#  '../../../dashlink-data/Tail_687_8/687200312271741.mat',
#  '../../../dashlink-data/Tail_687_8/687200309121638.mat',
#  '../../../dashlink-data/Tail_687_8/687200403080851.mat',
#  '../../../dashlink-data/Tail_687_8/687200402010922.mat',
#  '../../../dashlink-data/Tail_687_8/687200402100951.mat',
#  '../../../dashlink-data/Tail_687_8/687200312241756.mat',
#  '../../../dashlink-data/Tail_687_8/687200403140929.mat',
#  '../../../dashlink-data/Tail_687_8/687200402262355.mat',
#  '../../../dashlink-data/Tail_687_8/687200403091259.mat',
#  '../../../dashlink-data/Tail_687_8/687200311141237.mat',
#  '../../../dashlink-data/Tail_687_8/687200403171121.mat',
#  '../../../dashlink-data/Tail_687_8/687200312021528.mat',
#  '../../../dashlink-data/Tail_687_8/687200403020703.mat',
#  '../../../dashlink-data/Tail_687_8/687200311291800.mat',
#  '../../../dashlink-data/Tail_687_8/687200403021245.mat',
#  '../../../dashlink-data/Tail_687_8/687200403061521.mat',
#  '../../../dashlink-data/Tail_687_8/687200402021225_1.mat',
#  '../../../dashlink-data/Tail_687_8/687200311291027.mat',
#  '../../../dashlink-data/Tail_687_8/687200402080805.mat',
#  '../../../dashlink-data/Tail_687_8/687200402241745.mat',
#  '../../../dashlink-data/Tail_687_8/687200403190756.mat',
#  '../../../dashlink-data/Tail_687_8/687200311060744.mat',
#  '../../../dashlink-data/Tail_687_8/687200311120911.mat',
#  '../../../dashlink-data/Tail_687_8/687200401271713.mat',
#  '../../../dashlink-data/Tail_687_8/687200312291154.mat',
#  '../../../dashlink-data/Tail_687_8/687200403111322.mat',
#  '../../../dashlink-data/Tail_687_8/687200312040718.mat',
#  '../../../dashlink-data/Tail_687_8/687200401022158.mat',
#  '../../../dashlink-data/Tail_687_8/687200402232340.mat',
#  '../../../dashlink-data/Tail_687_8/687200402250925.mat',
#  '../../../dashlink-data/Tail_687_8/687200311041838.mat',
#  '../../../dashlink-data/Tail_687_8/687200403150719.mat',
#  '../../../dashlink-data/Tail_687_8/687200402120919.mat',
#  '../../../dashlink-data/Tail_687_8/687200311171432.mat',
#  '../../../dashlink-data/Tail_687_8/687200312161723.mat',
#  '../../../dashlink-data/Tail_687_8/687200310300903.mat',
#  '../../../dashlink-data/Tail_687_8/687200401271016.mat',
#  '../../../dashlink-data/Tail_687_8/687200311012200.mat',
#  '../../../dashlink-data/Tail_687_8/687200403191711.mat',
#  '../../../dashlink-data/Tail_687_8/687200403071051.mat',
#  '../../../dashlink-data/Tail_687_8/687200311082149.mat',
#  '../../../dashlink-data/Tail_687_8/687200403121312.mat',
#  '../../../dashlink-data/Tail_687_8/687200311130936.mat',
#  '../../../dashlink-data/Tail_687_8/687200312251412.mat',
#  '../../../dashlink-data/Tail_687_8/687200401030943.mat',
#  '../../../dashlink-data/Tail_687_8/687200403031257.mat',
#  '../../../dashlink-data/Tail_687_8/687200403111520.mat',
#  '../../../dashlink-data/Tail_687_8/687200403130701.mat',
#  '../../../dashlink-data/Tail_687_8/687200309130639.mat',
#  '../../../dashlink-data/Tail_687_8/687200403210534.mat',
#  '../../../dashlink-data/Tail_687_8/687200401291901.mat',
#  '../../../dashlink-data/Tail_687_8/687200403061024.mat',
#  '../../../dashlink-data/Tail_687_8/687200309081016.mat',
#  '../../../dashlink-data/Tail_687_8/687200403071312.mat',
#  '../../../dashlink-data/Tail_687_8/687200311061548.mat',
#  '../../../dashlink-data/Tail_687_8/687200402080449.mat',
#  '../../../dashlink-data/Tail_687_8/687200312250857.mat',
#  '../../../dashlink-data/Tail_687_8/687200402241014.mat',
#  '../../../dashlink-data/Tail_687_8/687200312180919.mat',
#  '../../../dashlink-data/Tail_687_8/687200312222144.mat',
#  '../../../dashlink-data/Tail_687_8/687200311291526.mat',
#  '../../../dashlink-data/Tail_687_8/687200309120817.mat',
#  '../../../dashlink-data/Tail_687_8/687200312232036.mat',
#  '../../../dashlink-data/Tail_687_8/687200311011459.mat',
#  '../../../dashlink-data/Tail_687_8/687200309131906.mat',
#  '../../../dashlink-data/Tail_687_8/687200401291314.mat',
#  '../../../dashlink-data/Tail_687_8/687200401261807.mat',
#  '../../../dashlink-data/Tail_687_8/687200312282145.mat',
#  '../../../dashlink-data/Tail_687_8/687200402081357.mat',
#  '../../../dashlink-data/Tail_687_8/687200403162122.mat',
#  '../../../dashlink-data/Tail_687_8/687200311051949.mat',
#  '../../../dashlink-data/Tail_687_8/687200403091446.mat',
#  '../../../dashlink-data/Tail_687_8/687200310311534.mat',
#  '../../../dashlink-data/Tail_687_8/687200403070941.mat',
#  '../../../dashlink-data/Tail_687_8/687200311161159.mat',
#  '../../../dashlink-data/Tail_687_8/687200401011035.mat',
#  '../../../dashlink-data/Tail_687_8/687200403131319.mat',
#  '../../../dashlink-data/Tail_687_8/687200401300706.mat',
#  '../../../dashlink-data/Tail_687_8/687200312031250.mat',
#  '../../../dashlink-data/Tail_687_8/687200309131040.mat',
#  '../../../dashlink-data/Tail_687_8/687200311140901.mat',
#  '../../../dashlink-data/Tail_687_8/687200403241405.mat',
#  '../../../dashlink-data/Tail_687_8/687200403010939.mat',
#  '../../../dashlink-data/Tail_687_8/687200311020651.mat',
#  '../../../dashlink-data/Tail_687_8/687200402010621.mat',
#  '../../../dashlink-data/Tail_687_8/687200401031212.mat',
#  '../../../dashlink-data/Tail_687_8/687200310300537.mat',
#  '../../../dashlink-data/Tail_687_8/687200311091747.mat',
#  '../../../dashlink-data/Tail_687_8/687200309091058.mat',
#  '../../../dashlink-data/Tail_687_8/687200403011221.mat',
#  '../../../dashlink-data/Tail_687_8/687200312240602.mat',
#  '../../../dashlink-data/Tail_687_8/687200311160638.mat',
#  '../../../dashlink-data/Tail_687_8/687200402021436.mat',
#  '../../../dashlink-data/Tail_687_8/687200403011930.mat',
#  '../../../dashlink-data/Tail_687_8/687200403100725.mat',
#  '../../../dashlink-data/Tail_687_8/687200402091838.mat',
#  '../../../dashlink-data/Tail_687_8/687200402070547.mat',
#  '../../../dashlink-data/Tail_687_8/687200403180930.mat',
#  '../../../dashlink-data/Tail_687_8/687200311030738.mat',
#  '../../../dashlink-data/Tail_687_8/687200309081534.mat',
#  '../../../dashlink-data/Tail_687_8/687200403060817.mat',
#  '../../../dashlink-data/Tail_687_8/687200312051521.mat',
#  '../../../dashlink-data/Tail_687_8/687200311121237.mat',
#  '../../../dashlink-data/Tail_687_8/687200402111355.mat',
#  '../../../dashlink-data/Tail_687_8/687200312161442.mat',
#  '../../../dashlink-data/Tail_687_8/687200403041844.mat',
#  '../../../dashlink-data/Tail_687_8/687200403170551.mat',
#  '../../../dashlink-data/Tail_687_8/687200403141950.mat',
#  '../../../dashlink-data/Tail_687_8/687200403251108.mat',
#  '../../../dashlink-data/Tail_687_8/687200402260940.mat',
#  '../../../dashlink-data/Tail_687_8/687200311150546.mat',
#  '../../../dashlink-data/Tail_687_8/687200311301435.mat',
#  '../../../dashlink-data/Tail_687_8/687200403191152.mat',
#  '../../../dashlink-data/Tail_687_8/687200311301138.mat',
#  '../../../dashlink-data/Tail_687_8/687200403221154.mat',
#  '../../../dashlink-data/Tail_687_8/687200311161501.mat',
#  '../../../dashlink-data/Tail_687_8/687200311031654.mat',
#  '../../../dashlink-data/Tail_687_8/687200312181147.mat',
#  '../../../dashlink-data/Tail_687_8/687200402111711.mat',
#  '../../../dashlink-data/Tail_687_8/687200312050931.mat',
#  '../../../dashlink-data/Tail_687_8/687200312251100.mat',
#  '../../../dashlink-data/Tail_687_8/687200403140752.mat',
#  '../../../dashlink-data/Tail_687_8/687200403170801.mat',
#  '../../../dashlink-data/Tail_687_8/687200403151252.mat',
#  '../../../dashlink-data/Tail_687_8/687200403230913.mat',
#  '../../../dashlink-data/Tail_687_8/687200402270430.mat',
#  '../../../dashlink-data/Tail_687_8/687200401301405.mat',
#  '../../../dashlink-data/Tail_687_8/687200403212049.mat',
#  '../../../dashlink-data/Tail_687_8/687200312310505.mat',
#  '../../../dashlink-data/Tail_687_8/687200309091905.mat',
#  '../../../dashlink-data/Tail_687_8/687200401290815.mat',
#  '../../../dashlink-data/Tail_687_8/687200403151644.mat',
#  '../../../dashlink-data/Tail_687_8/687200311091246.mat',
#  '../../../dashlink-data/Tail_687_8/687200402071132.mat',
#  '../../../dashlink-data/Tail_687_8/687200402041314.mat',
#  '../../../dashlink-data/Tail_687_8/687200311170950.mat',
#  '../../../dashlink-data/Tail_687_8/687200402051028.mat',
#  '../../../dashlink-data/Tail_687_8/687200312010731.mat',
#  '../../../dashlink-data/Tail_687_8/687200401011259.mat',
#  '../../../dashlink-data/Tail_687_8/687200401281206.mat',
#  '../../../dashlink-data/Tail_687_8/687200402241345.mat',
#  '../../../dashlink-data/Tail_687_8/687200402010508.mat',
#  '../../../dashlink-data/Tail_687_8/687200311111230.mat',
#  '../../../dashlink-data/Tail_687_8/687200312241154.mat',
#  '../../../dashlink-data/Tail_687_8/687200312041756.mat',
#  '../../../dashlink-data/Tail_687_8/687200311071904.mat',
#  '../../../dashlink-data/Tail_687_8/687200311291302.mat',
#  '../../../dashlink-data/Tail_687_8/687200311051722.mat',
#  '../../../dashlink-data/Tail_687_8/687200402061004.mat',
#  '../../../dashlink-data/Tail_687_8/687200309111358.mat',
#  '../../../dashlink-data/Tail_687_8/687200403031938.mat',
#  '../../../dashlink-data/Tail_687_8/687200403121502.mat',
#  '../../../dashlink-data/Tail_687_8/687200401301636.mat',
#  '../../../dashlink-data/Tail_687_8/687200403200701.mat',
#  '../../../dashlink-data/Tail_687_8/687200403151455.mat',
#  '../../../dashlink-data/Tail_687_8/687200402040740.mat',
#  '../../../dashlink-data/Tail_687_8/687200403240544.mat',
#  '../../../dashlink-data/Tail_687_8/687200403120338.mat',
#  '../../../dashlink-data/Tail_687_8/687200311280619.mat',
#  '../../../dashlink-data/Tail_687_8/687200310290826.mat',
#  '../../../dashlink-data/Tail_687_8/687200312260625.mat',
#  '../../../dashlink-data/Tail_687_8/687200401301935.mat',
#  '../../../dashlink-data/Tail_687_8/687200403220337.mat',
#  '../../../dashlink-data/Tail_687_8/687200403221337.mat',
#  '../../../dashlink-data/Tail_687_8/687200402031946.mat',
#  '../../../dashlink-data/Tail_687_8/687200311120448.mat',
#  '../../../dashlink-data/Tail_687_8/687200312281716.mat',
#  '../../../dashlink-data/Tail_687_8/687200309111635.mat',
#  '../../../dashlink-data/Tail_687_8/687200312190335.mat',
#  '../../../dashlink-data/Tail_687_8/687200311152058.mat',
#  '../../../dashlink-data/Tail_687_8/687200311061417.mat',
#  '../../../dashlink-data/Tail_687_8/687200403171448.mat',
#  '../../../dashlink-data/Tail_687_8/687200309110815.mat',
#  '../../../dashlink-data/Tail_687_8/687200402271442.mat',
#  '../../../dashlink-data/Tail_687_8/687200401291009.mat',
#  '../../../dashlink-data/Tail_687_8/687200402071800.mat',
#  '../../../dashlink-data/Tail_687_8/687200402120445.mat',
#  '../../../dashlink-data/Tail_687_8/687200312261446.mat',
#  '../../../dashlink-data/Tail_687_8/687200310301810.mat',
#  '../../../dashlink-data/Tail_687_8/687200402081626.mat',
#  '../../../dashlink-data/Tail_687_8/687200401030736.mat',
#  '../../../dashlink-data/Tail_687_8/687200311021435.mat',
#  '../../../dashlink-data/Tail_687_8/687200403010715.mat',
#  '../../../dashlink-data/Tail_687_8/687200312231719.mat',
#  '../../../dashlink-data/Tail_687_8/687200403181321.mat',
#  '../../../dashlink-data/Tail_687_8/687200402281126.mat',
#  '../../../dashlink-data/Tail_687_8/687200311021602.mat',
#  '../../../dashlink-data/Tail_687_8/687200403180748.mat',
#  '../../../dashlink-data/Tail_687_8/687200311261418.mat',
#  '../../../dashlink-data/Tail_687_8/687200402011919.mat',
#  '../../../dashlink-data/Tail_687_8/687200309071652.mat',
#  '../../../dashlink-data/Tail_687_8/687200403162015.mat',
#  '../../../dashlink-data/Tail_687_8/687200403221956.mat',
#  '../../../dashlink-data/Tail_687_8/687200403031623.mat',
#  '../../../dashlink-data/Tail_687_8/687200311270511.mat',
#  '../../../dashlink-data/Tail_687_8/687200310310612.mat',
#  '../../../dashlink-data/Tail_687_8/687200403181521.mat',
#  '../../../dashlink-data/Tail_687_8/687200403130714.mat',
#  '../../../dashlink-data/Tail_687_8/687200311081633.mat',
#  '../../../dashlink-data/Tail_687_8/687200403030641.mat',
#  '../../../dashlink-data/Tail_687_8/687200402030359.mat',
#  '../../../dashlink-data/Tail_687_8/687200402250640.mat',
#  '../../../dashlink-data/Tail_687_8/687200311010818.mat',
#  '../../../dashlink-data/Tail_687_8/687200311051319.mat',
#  '../../../dashlink-data/Tail_687_8/687200310290129.mat',
#  '../../../dashlink-data/Tail_687_8/687200401310806.mat',
#  '../../../dashlink-data/Tail_687_8/687200403050654.mat',
#  '../../../dashlink-data/Tail_687_8/687200312290609.mat',
#  '../../../dashlink-data/Tail_687_8/687200402280536.mat',
#  '../../../dashlink-data/Tail_687_8/687200401280823.mat',
#  '../../../dashlink-data/Tail_687_8/687200309080533.mat',
#  '../../../dashlink-data/Tail_687_8/687200402101014.mat',
#  '../../../dashlink-data/Tail_687_8/687200403030921.mat',
#  '../../../dashlink-data/Tail_687_2/687200111280824.mat',
#  '../../../dashlink-data/Tail_687_2/687200112251353.mat',
#  '../../../dashlink-data/Tail_687_2/687200112011821.mat',
#  '../../../dashlink-data/Tail_687_2/687200110221551.mat',
#  '../../../dashlink-data/Tail_687_2/687200111291903.mat',
#  '../../../dashlink-data/Tail_687_2/687200109151635.mat',
#  '../../../dashlink-data/Tail_687_2/687200110071255.mat',
#  '../../../dashlink-data/Tail_687_2/687200109151042.mat',
#  '../../../dashlink-data/Tail_687_2/687200110061256.mat',
#  '../../../dashlink-data/Tail_687_2/687200112150439.mat',
#  '../../../dashlink-data/Tail_687_2/687200112231839.mat',
#  '../../../dashlink-data/Tail_687_2/687200111271037.mat',
#  '../../../dashlink-data/Tail_687_2/687200111300551.mat',
#  '../../../dashlink-data/Tail_687_2/687200109282038.mat',
#  '../../../dashlink-data/Tail_687_2/687200111141905.mat',
#  '../../../dashlink-data/Tail_687_2/687200111282047.mat',
#  '../../../dashlink-data/Tail_687_2/687200111051448.mat',
#  '../../../dashlink-data/Tail_687_2/687200112101829.mat',
#  '../../../dashlink-data/Tail_687_2/687200111220535.mat',
#  '../../../dashlink-data/Tail_687_2/687200112232028.mat',
#  '../../../dashlink-data/Tail_687_2/687200112271908.mat',
#  '../../../dashlink-data/Tail_687_2/687200111011856.mat',
#  '../../../dashlink-data/Tail_687_2/687200112060741.mat',
#  '../../../dashlink-data/Tail_687_2/687200111151250.mat',
#  '../../../dashlink-data/Tail_687_2/687200110062033.mat',
#  '../../../dashlink-data/Tail_687_2/687200111121559.mat',
#  '../../../dashlink-data/Tail_687_2/687200109192106.mat',
#  '../../../dashlink-data/Tail_687_2/687200110111109.mat',
#  '../../../dashlink-data/Tail_687_2/687200109191857.mat',
#  '../../../dashlink-data/Tail_687_2/687200109251724.mat',
#  '../../../dashlink-data/Tail_687_2/687200109271751.mat',
#  '../../../dashlink-data/Tail_687_2/687200112150934.mat',
#  '../../../dashlink-data/Tail_687_2/687200111170640.mat',
#  '../../../dashlink-data/Tail_687_2/687200109180543.mat',
#  '../../../dashlink-data/Tail_687_2/687200111250900.mat',
#  '../../../dashlink-data/Tail_687_2/687200112240401.mat',
#  '../../../dashlink-data/Tail_687_2/687200109261129.mat',
#  '../../../dashlink-data/Tail_687_2/687200109171925.mat',
#  '../../../dashlink-data/Tail_687_2/687200110180559.mat',
#  '../../../dashlink-data/Tail_687_2/687200111120931.mat',
#  '../../../dashlink-data/Tail_687_2/687200109200502.mat',
#  '../../../dashlink-data/Tail_687_2/687200110270942.mat',
#  '../../../dashlink-data/Tail_687_2/687200111041923.mat',
#  '../../../dashlink-data/Tail_687_2/687200111160639.mat',
#  '../../../dashlink-data/Tail_687_2/687200109242116.mat',
#  '../../../dashlink-data/Tail_687_2/687200111141251.mat',
#  '../../../dashlink-data/Tail_687_2/687200110190441.mat',
#  '../../../dashlink-data/Tail_687_2/687200111300649.mat',
#  '../../../dashlink-data/Tail_687_2/687200111011444.mat',
#  '../../../dashlink-data/Tail_687_2/687200112241102.mat',
#  '../../../dashlink-data/Tail_687_2/687200112151729.mat',
#  '../../../dashlink-data/Tail_687_2/687200112250831.mat',
#  '../../../dashlink-data/Tail_687_2/687200112171049.mat',
#  '../../../dashlink-data/Tail_687_2/687200110181729.mat',
#  '../../../dashlink-data/Tail_687_2/687200110151437.mat',
#  '../../../dashlink-data/Tail_687_2/687200111151835.mat',
#  '../../../dashlink-data/Tail_687_2/687200109230456.mat',
#  '../../../dashlink-data/Tail_687_2/687200111211832.mat',
#  '../../../dashlink-data/Tail_687_2/687200109221225.mat',
#  '../../../dashlink-data/Tail_687_2/687200109281344.mat',
#  '../../../dashlink-data/Tail_687_2/687200111070703.mat',
#  '../../../dashlink-data/Tail_687_2/687200110010658.mat',
#  '../../../dashlink-data/Tail_687_2/687200110161102.mat',
#  '../../../dashlink-data/Tail_687_2/687200111261627.mat',
#  '../../../dashlink-data/Tail_687_2/687200112200904.mat',
#  '../../../dashlink-data/Tail_687_2/687200111151529.mat',
#  '../../../dashlink-data/Tail_687_2/687200111261212.mat',
#  '../../../dashlink-data/Tail_687_2/687200112041713.mat',
#  '../../../dashlink-data/Tail_687_2/687200111231250.mat',
#  '../../../dashlink-data/Tail_687_2/687200110051622.mat',
#  '../../../dashlink-data/Tail_687_2/687200110280535.mat',
#  '../../../dashlink-data/Tail_687_2/687200111041025.mat',
#  '../../../dashlink-data/Tail_687_2/687200111261057.mat',
#  '../../../dashlink-data/Tail_687_2/687200110191210.mat',
#  '../../../dashlink-data/Tail_687_2/687200110101444.mat',
#  '../../../dashlink-data/Tail_687_2/687200109161224.mat',
#  '../../../dashlink-data/Tail_687_2/687200112101612.mat',
#  '../../../dashlink-data/Tail_687_2/687200109161929.mat',
#  '../../../dashlink-data/Tail_687_2/687200109222059.mat',
#  '../../../dashlink-data/Tail_687_2/687200112130629.mat',
#  '../../../dashlink-data/Tail_687_2/687200109191256.mat',
#  '../../../dashlink-data/Tail_687_2/687200112020701.mat',
#  '../../../dashlink-data/Tail_687_2/687200112142049.mat',
#  '../../../dashlink-data/Tail_687_2/687200109230829.mat',
#  '../../../dashlink-data/Tail_687_2/687200110291055.mat',
#  '../../../dashlink-data/Tail_687_2/687200110131103.mat',
#  '../../../dashlink-data/Tail_687_2/687200111011612.mat',
#  '../../../dashlink-data/Tail_687_2/687200111242107.mat',
#  '../../../dashlink-data/Tail_687_2/687200110311822.mat',
#  '../../../dashlink-data/Tail_687_2/687200111011149.mat',
#  '../../../dashlink-data/Tail_687_2/687200111161836.mat',
#  '../../../dashlink-data/Tail_687_2/687200112131613.mat',
#  '../../../dashlink-data/Tail_687_2/687200112191836.mat',
#  '../../../dashlink-data/Tail_687_2/687200110051748.mat',
#  '../../../dashlink-data/Tail_687_2/687200109241410.mat',
#  '../../../dashlink-data/Tail_687_2/687200110302156.mat',
#  '../../../dashlink-data/Tail_687_2/687200109250818.mat',
#  '../../../dashlink-data/Tail_687_2/687200112151936.mat',
#  '../../../dashlink-data/Tail_687_2/687200110191027.mat',
#  '../../../dashlink-data/Tail_687_2/687200110020841.mat',
#  '../../../dashlink-data/Tail_687_2/687200110031936.mat',
#  '../../../dashlink-data/Tail_687_2/687200112271246.mat',
#  '../../../dashlink-data/Tail_687_2/687200109231431.mat',
#  '../../../dashlink-data/Tail_687_2/687200111301535.mat',
#  '../../../dashlink-data/Tail_687_2/687200109162052.mat',
#  '../../../dashlink-data/Tail_687_2/687200110031541.mat',
#  '../../../dashlink-data/Tail_687_2/687200111131332.mat',
#  '../../../dashlink-data/Tail_687_2/687200112281448.mat',
#  '../../../dashlink-data/Tail_687_2/687200110080903.mat',
#  '../../../dashlink-data/Tail_687_2/687200112030859.mat',
#  '../../../dashlink-data/Tail_687_2/687200112141248.mat',
#  '../../../dashlink-data/Tail_687_2/687200109301629.mat',
#  '../../../dashlink-data/Tail_687_2/687200112051221.mat',
#  '../../../dashlink-data/Tail_687_2/687200112251717.mat',
#  '../../../dashlink-data/Tail_687_2/687200110251135.mat',
#  '../../../dashlink-data/Tail_687_2/687200112160519.mat',
#  '../../../dashlink-data/Tail_687_2/687200110031242.mat',
#  '../../../dashlink-data/Tail_687_2/687200110241145.mat',
#  '../../../dashlink-data/Tail_687_2/687200110150944.mat',
#  '../../../dashlink-data/Tail_687_2/687200112251355.mat',
#  '../../../dashlink-data/Tail_687_2/687200112021819.mat',
#  '../../../dashlink-data/Tail_687_2/687200110071744.mat',
#  '../../../dashlink-data/Tail_687_2/687200112261100.mat',
#  '../../../dashlink-data/Tail_687_2/687200109182126.mat',
#  '../../../dashlink-data/Tail_687_2/687200111251304.mat',
#  '../../../dashlink-data/Tail_687_2/687200110151831.mat',
#  '../../../dashlink-data/Tail_687_2/687200110290644.mat',
#  '../../../dashlink-data/Tail_687_2/687200110140539.mat',
#  '../../../dashlink-data/Tail_687_2/687200109251126.mat',
#  '../../../dashlink-data/Tail_687_2/687200110171817.mat',
#  '../../../dashlink-data/Tail_687_2/687200111150626.mat',
#  '../../../dashlink-data/Tail_687_2/687200110281114.mat',
#  '../../../dashlink-data/Tail_687_2/687200111211351.mat',
#  '../../../dashlink-data/Tail_687_2/687200109170402.mat',
#  '../../../dashlink-data/Tail_687_2/687200111300901.mat',
#  '../../../dashlink-data/Tail_687_2/687200111261942.mat',
#  '../../../dashlink-data/Tail_687_2/687200112291217.mat',
#  '../../../dashlink-data/Tail_687_2/687200111142145.mat',
#  '../../../dashlink-data/Tail_687_2/687200110292047.mat',
#  '../../../dashlink-data/Tail_687_2/687200110040546.mat',
#  '../../../dashlink-data/Tail_687_2/687200112110657.mat',
#  '../../../dashlink-data/Tail_687_2/687200112240529.mat',
#  '../../../dashlink-data/Tail_687_2/687200109170504.mat',
#  '../../../dashlink-data/Tail_687_2/687200110211033.mat',
#  '../../../dashlink-data/Tail_687_2/687200112150739.mat',
#  '../../../dashlink-data/Tail_687_2/687200109161730.mat',
#  '../../../dashlink-data/Tail_687_2/687200112270657.mat',
#  '../../../dashlink-data/Tail_687_2/687200111101805.mat',
#  '../../../dashlink-data/Tail_687_2/687200111041626.mat',
#  '../../../dashlink-data/Tail_687_2/687200112291838.mat',
#  '../../../dashlink-data/Tail_687_2/687200112151238.mat',
#  '../../../dashlink-data/Tail_687_2/687200110241856.mat',
#  '../../../dashlink-data/Tail_687_2/687200112191428.mat',
#  '../../../dashlink-data/Tail_687_2/687200111260819.mat',
#  '../../../dashlink-data/Tail_687_2/687200110162002.mat',
#  '../../../dashlink-data/Tail_687_2/687200111061156.mat',
#  '../../../dashlink-data/Tail_687_2/687200112201027.mat',
#  '../../../dashlink-data/Tail_687_2/687200111240654.mat',
#  '../../../dashlink-data/Tail_687_2/687200111221022.mat',
#  '../../../dashlink-data/Tail_687_2/687200109250413.mat',
#  '../../../dashlink-data/Tail_687_2/687200111091116.mat',
#  '../../../dashlink-data/Tail_687_2/687200111010541.mat',
#  '../../../dashlink-data/Tail_687_2/687200112211905.mat',
#  '../../../dashlink-data/Tail_687_2/687200112230651.mat',
#  '../../../dashlink-data/Tail_687_2/687200110301622.mat',
#  '../../../dashlink-data/Tail_687_2/687200109161538.mat',
#  '../../../dashlink-data/Tail_687_2/687200112061927.mat',
#  '../../../dashlink-data/Tail_687_2/687200111020934.mat',
#  '../../../dashlink-data/Tail_687_2/687200111111354.mat',
#  '../../../dashlink-data/Tail_687_2/687200110050909.mat',
#  '../../../dashlink-data/Tail_687_2/687200112141434.mat',
#  '../../../dashlink-data/Tail_687_2/687200112191008.mat',
#  '../../../dashlink-data/Tail_687_2/687200110272040.mat',
#  '../../../dashlink-data/Tail_687_2/687200112170624.mat',
#  '../../../dashlink-data/Tail_687_2/687200111241728.mat',
#  '../../../dashlink-data/Tail_687_2/687200112061350.mat',
#  '../../../dashlink-data/Tail_687_2/687200112200734.mat',
#  '../../../dashlink-data/Tail_687_2/687200112040904.mat',
#  '../../../dashlink-data/Tail_687_2/687200110171038.mat',
#  '../../../dashlink-data/Tail_687_2/687200110042011.mat',
#  '../../../dashlink-data/Tail_687_2/687200111151043.mat',
#  '../../../dashlink-data/Tail_687_2/687200110221411.mat',
#  '../../../dashlink-data/Tail_687_2/687200112061545.mat',
#  '../../../dashlink-data/Tail_687_2/687200112281624.mat',
#  '../../../dashlink-data/Tail_687_2/687200111241614.mat',
#  '../../../dashlink-data/Tail_687_2/687200111291104.mat',
#  '../../../dashlink-data/Tail_687_2/687200112231617.mat',
#  '../../../dashlink-data/Tail_687_2/687200111041404.mat',
#  '../../../dashlink-data/Tail_687_2/687200110221841.mat',
#  '../../../dashlink-data/Tail_687_2/687200109291840.mat',
#  '../../../dashlink-data/Tail_687_2/687200110200439.mat',
#  '../../../dashlink-data/Tail_687_2/687200111171050.mat',
#  '../../../dashlink-data/Tail_687_2/687200109221432.mat',
#  '../../../dashlink-data/Tail_687_2/687200110241133.mat',
#  '../../../dashlink-data/Tail_687_2/687200109251302.mat',
#  '../../../dashlink-data/Tail_687_2/687200111170835.mat',
#  '../../../dashlink-data/Tail_687_2/687200110050523.mat',
#  '../../../dashlink-data/Tail_687_2/687200110090850.mat',
#  '../../../dashlink-data/Tail_687_2/687200112311241.mat',
#  '../../../dashlink-data/Tail_687_2/687200109251839.mat',
#  '../../../dashlink-data/Tail_687_2/687200110221043.mat',
#  '../../../dashlink-data/Tail_687_2/687200109261609.mat',
#  '../../../dashlink-data/Tail_687_2/687200110170728.mat',
#  '../../../dashlink-data/Tail_687_2/687200112021311.mat',
#  '../../../dashlink-data/Tail_687_2/687200111231622.mat',
#  '../../../dashlink-data/Tail_687_2/687200111301301.mat',
#  '../../../dashlink-data/Tail_687_2/687200110261126.mat',
#  '../../../dashlink-data/Tail_687_2/687200112260909.mat',
#  '../../../dashlink-data/Tail_687_2/687200110180934.mat',
#  '../../../dashlink-data/Tail_687_2/687200109190845.mat',
#  '../../../dashlink-data/Tail_687_2/687200111210944.mat',
#  '../../../dashlink-data/Tail_687_2/687200111090935.mat',
#  '../../../dashlink-data/Tail_687_2/687200112241555.mat',
#  '../../../dashlink-data/Tail_687_2/687200111101552.mat',
#  '../../../dashlink-data/Tail_687_2/687200109181457.mat',
#  '../../../dashlink-data/Tail_687_2/687200112200648.mat',
#  '../../../dashlink-data/Tail_687_2/687200112291447.mat',
#  '../../../dashlink-data/Tail_687_2/687200111010849.mat',
#  '../../../dashlink-data/Tail_687_2/687200110131527.mat',
#  '../../../dashlink-data/Tail_687_2/687200109201901.mat',
#  '../../../dashlink-data/Tail_687_2/687200112101434.mat',
#  '../../../dashlink-data/Tail_687_2/687200111021154.mat',
#  '../../../dashlink-data/Tail_687_2/687200109181902.mat',
#  '../../../dashlink-data/Tail_687_2/687200111251048.mat',
#  '../../../dashlink-data/Tail_687_2/687200111111607.mat',
#  '../../../dashlink-data/Tail_687_2/687200111171403.mat',
#  '../../../dashlink-data/Tail_687_2/687200110100856.mat',
#  '../../../dashlink-data/Tail_687_2/687200110151135.mat',
#  '../../../dashlink-data/Tail_687_2/687200109251544.mat',
#  '../../../dashlink-data/Tail_687_2/687200110210606.mat',
#  '../../../dashlink-data/Tail_687_2/687200109171450.mat',
#  '../../../dashlink-data/Tail_687_2/687200111290951.mat',
#  '../../../dashlink-data/Tail_687_2/687200111110524.mat',
#  '../../../dashlink-data/Tail_687_2/687200110022059.mat',
#  '../../../dashlink-data/Tail_687_2/687200110141224.mat',
#  '../../../dashlink-data/Tail_687_2/687200112120656.mat',
#  '../../../dashlink-data/Tail_687_2/687200111101401.mat',
#  '../../../dashlink-data/Tail_687_2/687200111281056.mat',
#  '../../../dashlink-data/Tail_687_2/687200112261222.mat',
#  '../../../dashlink-data/Tail_687_2/687200110181533.mat',
#  '../../../dashlink-data/Tail_687_2/687200111241905.mat',
#  '../../../dashlink-data/Tail_687_2/687200109271155.mat',
#  '../../../dashlink-data/Tail_687_2/687200112132154.mat',
#  '../../../dashlink-data/Tail_687_2/687200109281037.mat',
#  '../../../dashlink-data/Tail_687_2/687200112231050.mat',
#  '../../../dashlink-data/Tail_687_2/687200110251403.mat',
#  '../../../dashlink-data/Tail_687_2/687200112021059.mat',
#  '../../../dashlink-data/Tail_687_2/687200111161408.mat',
#  '../../../dashlink-data/Tail_687_2/687200112301454.mat',
#  '../../../dashlink-data/Tail_687_2/687200109261718.mat',
#  '../../../dashlink-data/Tail_687_2/687200110230858.mat',
#  '../../../dashlink-data/Tail_687_2/687200111011017.mat',
#  '../../../dashlink-data/Tail_687_2/687200112271002.mat',
#  '../../../dashlink-data/Tail_687_2/687200109231648.mat',
#  '../../../dashlink-data/Tail_687_2/687200109241114.mat',
#  '../../../dashlink-data/Tail_687_2/687200111060733.mat',
#  '../../../dashlink-data/Tail_687_2/687200109240430.mat',
#  '../../../dashlink-data/Tail_687_2/687200109301821.mat',
#  '../../../dashlink-data/Tail_687_2/687200109270444.mat',
#  '../../../dashlink-data/Tail_687_2/687200109200513.mat',
#  '../../../dashlink-data/Tail_687_2/687200110171559.mat',
#  '../../../dashlink-data/Tail_687_2/687200112310928.mat',
#  '../../../dashlink-data/Tail_687_2/687200111050955.mat',
#  '../../../dashlink-data/Tail_687_2/687200109221017.mat',
#  '../../../dashlink-data/Tail_687_2/687200110271715.mat',
#  '../../../dashlink-data/Tail_687_2/687200111271252.mat',
#  '../../../dashlink-data/Tail_687_2/687200110151617.mat',
#  '../../../dashlink-data/Tail_687_2/687200109270750.mat',
#  '../../../dashlink-data/Tail_687_2/687200110311616.mat',
#  '../../../dashlink-data/Tail_687_2/687200112302033.mat',
#  '../../../dashlink-data/Tail_687_2/687200110142008.mat',
#  '../../../dashlink-data/Tail_687_2/687200110021642.mat',
#  '../../../dashlink-data/Tail_687_2/687200109171052.mat',
#  '../../../dashlink-data/Tail_687_2/687200112062118.mat',
#  '../../../dashlink-data/Tail_687_2/687200112211249.mat',
#  '../../../dashlink-data/Tail_687_2/687200110160848.mat',
#  '../../../dashlink-data/Tail_687_2/687200112010811.mat',
#  '../../../dashlink-data/Tail_687_2/687200111021552.mat',
#  '../../../dashlink-data/Tail_687_2/687200110021356.mat',
#  '../../../dashlink-data/Tail_687_2/687200111241131.mat',
#  '../../../dashlink-data/Tail_687_2/687200110310707.mat',
#  '../../../dashlink-data/Tail_687_2/687200109141240.mat',
#  '../../../dashlink-data/Tail_687_2/687200112051817.mat',
#  '../../../dashlink-data/Tail_687_2/687200109171714.mat',
#  '../../../dashlink-data/Tail_687_2/687200111031155.mat',
#  '../../../dashlink-data/Tail_687_2/687200110091505.mat',
#  '../../../dashlink-data/Tail_687_2/687200109271927.mat',
#  '../../../dashlink-data/Tail_687_2/687200110201813.mat',
#  '../../../dashlink-data/Tail_687_2/687200111061727.mat',
#  '../../../dashlink-data/Tail_687_2/687200110140908.mat',
#  '../../../dashlink-data/Tail_687_2/687200112021355.mat',
#  '../../../dashlink-data/Tail_687_2/687200111061349.mat',
#  '../../../dashlink-data/Tail_687_2/687200109260619.mat',
#  '../../../dashlink-data/Tail_687_2/687200111161612.mat',
#  '../../../dashlink-data/Tail_687_2/687200110211318.mat',
#  '../../../dashlink-data/Tail_687_2/687200110300926.mat',
#  '../../../dashlink-data/Tail_687_2/687200111180935.mat',
#  '../../../dashlink-data/Tail_687_2/687200110141719.mat',
#  '../../../dashlink-data/Tail_687_2/687200111141638.mat',
#  '../../../dashlink-data/Tail_687_2/687200112051723.mat',
#  '../../../dashlink-data/Tail_687_2/687200109180803.mat',
#  '../../../dashlink-data/Tail_687_2/687200110291240.mat',
#  '../../../dashlink-data/Tail_687_2/687200112200538.mat',
#  '../../../dashlink-data/Tail_687_2/687200112152101.mat',
#  '../../../dashlink-data/Tail_687_2/687200111270854.mat',
#  '../../../dashlink-data/Tail_687_2/687200112021219.mat',
#  '../../../dashlink-data/Tail_687_2/687200109151958.mat',
#  '../../../dashlink-data/Tail_687_2/687200112031536.mat',
#  '../../../dashlink-data/Tail_687_2/687200109301343.mat',
#  '../../../dashlink-data/Tail_687_2/687200110081217.mat',
#  '../../../dashlink-data/Tail_687_2/687200111030821.mat',
#  '../../../dashlink-data/Tail_687_2/687200111231446.mat',
#  '../../../dashlink-data/Tail_687_2/687200112121058.mat',
#  '../../../dashlink-data/Tail_687_2/687200111081923.mat',
#  '../../../dashlink-data/Tail_687_2/687200112031311.mat',
#  '../../../dashlink-data/Tail_687_2/687200112111815.mat',
#  '../../../dashlink-data/Tail_687_2/687200111221735.mat',
#  '../../../dashlink-data/Tail_687_2/687200109141722.mat',
#  '../../../dashlink-data/Tail_687_2/687200109180517.mat',
#  '../../../dashlink-data/Tail_687_2/687200109290840.mat',
#  '../../../dashlink-data/Tail_687_2/687200112211637.mat',
#  '../../../dashlink-data/Tail_687_2/687200110210901.mat',
#  '../../../dashlink-data/Tail_687_2/687200110071544.mat',
#  '../../../dashlink-data/Tail_687_2/687200110260906.mat',
#  '../../../dashlink-data/Tail_687_2/687200112300636.mat',
#  '../../../dashlink-data/Tail_687_2/687200109201301.mat',
#  '../../../dashlink-data/Tail_687_2/687200110251919.mat',
#  '../../../dashlink-data/Tail_687_2/687200112031726.mat',
#  '../../../dashlink-data/Tail_687_2/687200111062043.mat',
#  '../../../dashlink-data/Tail_687_2/687200111301730.mat',
#  '../../../dashlink-data/Tail_687_2/687200112170851.mat',
#  '../../../dashlink-data/Tail_687_2/687200110030650.mat',
#  '../../../dashlink-data/Tail_687_2/687200110211634.mat',
#  '../../../dashlink-data/Tail_687_2/687200112231222.mat',
#  '../../../dashlink-data/Tail_687_2/687200111281353.mat',
#  '../../../dashlink-data/Tail_687_2/687200109210606.mat',
#  '../../../dashlink-data/Tail_687_2/687200111091938.mat',
#  '../../../dashlink-data/Tail_687_2/687200111070504.mat',
#  '../../../dashlink-data/Tail_687_2/687200109171227.mat',
#  '../../../dashlink-data/Tail_687_2/687200111161051.mat',
#  '../../../dashlink-data/Tail_687_2/687200109201711.mat',
#  '../../../dashlink-data/Tail_687_2/687200109161350.mat',
#  '../../../dashlink-data/Tail_687_2/687200111101002.mat',
#  '../../../dashlink-data/Tail_687_2/687200111291429.mat',
#  '../../../dashlink-data/Tail_687_2/687200109150838.mat',
#  '../../../dashlink-data/Tail_687_2/687200109261955.mat',
#  '../../../dashlink-data/Tail_687_2/687200112011242.mat',
#  '../../../dashlink-data/Tail_687_2/687200110040905.mat',
#  '../../../dashlink-data/Tail_687_2/687200110231943.mat',
#  '../../../dashlink-data/Tail_687_2/687200111071044.mat',
#  '../../../dashlink-data/Tail_687_2/687200109251004.mat',
#  '../../../dashlink-data/Tail_687_2/687200110242256.mat',
#  '../../../dashlink-data/Tail_687_2/687200111081354.mat',
#  '../../../dashlink-data/Tail_687_2/687200111200937.mat',
#  '../../../dashlink-data/Tail_687_2/687200110201542.mat',
#  '../../../dashlink-data/Tail_687_2/687200110041436.mat',
#  '../../../dashlink-data/Tail_687_2/687200110011057.mat',
#  '../../../dashlink-data/Tail_687_2/687200109211505.mat',
#  '../../../dashlink-data/Tail_687_2/687200111020604.mat',
#  '../../../dashlink-data/Tail_687_2/687200111211542.mat',
#  '../../../dashlink-data/Tail_687_2/687200111281213.mat',
#  '../../../dashlink-data/Tail_687_2/687200110091822.mat',
#  '../../../dashlink-data/Tail_687_2/687200110010500.mat',
#  '../../../dashlink-data/Tail_687_2/687200112011637.mat',
#  '../../../dashlink-data/Tail_687_2/687200111061026.mat',
#  '../../../dashlink-data/Tail_687_2/687200111141007.mat',
#  '../../../dashlink-data/Tail_687_2/687200112300909.mat',
#  '../../../dashlink-data/Tail_687_2/687200111101131.mat',
#  '../../../dashlink-data/Tail_687_2/687200109211256.mat',
#  '../../../dashlink-data/Tail_687_2/687200109231845.mat',
#  '../../../dashlink-data/Tail_687_2/687200110112118.mat',
#  '../../../dashlink-data/Tail_687_2/687200111071318.mat',
#  '../../../dashlink-data/Tail_687_2/687200110290548.mat',
#  '../../../dashlink-data/Tail_687_2/687200110141444.mat',
#  '../../../dashlink-data/Tail_687_2/687200112220914.mat',
#  '../../../dashlink-data/Tail_687_2/687200112291621.mat',
#  '../../../dashlink-data/Tail_687_2/687200112011001.mat',
#  ...]

# %% [markdown]
# ### Step 1b: Isolate landing data at MSP at specified heights
# According to the DASHlink website, the ```PH``` enumerated codes are:
# - 0=Unknown
# - 1=Preflight
# - 2=Taxi
# - 3=Takeoff
# - 4=Climb
# - 5=Cruise
# - 6=Approach
# - 7=Rollout
#
# Here we are interested in ```PH = 7``` at heights of 200,100,50,40,30,20,10,8,6,4,2, and 0 feet above landing altitude.

# %%
PHASE_NO = 7
MSP_AIRPORT_LAT_LON = [44.88526995556498, -93.2015923365669]
HEIGHT_LIST = np.array([200,100,50,40,30,20,10,8,6,4,2,0])

# %%
from dataUtils import DASHlinkData

key_list_25=['LATP','LONP','MSQT_1','BAL1','TAS','GS','TH','FLAP','GLS','LOC','N1_1','PTCH','ROLL','TRK','AIL_1','RUDD','ELEV_1',\
         'BLAC','CTAC','FPAC','CCPC','CWPC','WS','WD','ALTR']

SUBSET_FOR_DEMO = 5376
dfs = []

for i,mat_file in enumerate(downloaded_mat_files[:SUBSET_FOR_DEMO]):
    print("Processing {} of {} .mat files.".format(i+1,len(downloaded_mat_files)))
    dl_data = DASHlinkData(mat_file)
    if dl_data.contains_phase_no(phase=PHASE_NO):
        if dl_data.lands_at_airport(airport_lat_lon=MSP_AIRPORT_LAT_LON):
            for key in key_list_25:
                dl_data.temporal_resample_to_4_seconds(key)
            df_new = dl_data.get_data_at_heights_in_ft(HEIGHT_LIST)
            dfs.append(df_new)

df_landing = pd.concat(dfs)
# Out:
# Processing 1 of 5376 .mat files.
# Processing 2 of 5376 .mat files.
# Processing 3 of 5376 .mat files.
# Processing 4 of 5376 .mat files.
# Processing 5 of 5376 .mat files.
# Processing 6 of 5376 .mat files.
# Processing 7 of 5376 .mat files.
# Processing 8 of 5376 .mat files.
# Processing 9 of 5376 .mat files.
# Processing 10 of 5376 .mat files.
# Processing 11 of 5376 .mat files.
# Processing 12 of 5376 .mat files.
# Processing 13 of 5376 .mat files.
# Processing 14 of 5376 .mat files.
# Processing 15 of 5376 .mat files.
# Processing 16 of 5376 .mat files.
# Processing 17 of 5376 .mat files.
# Processing 18 of 5376 .mat files.
# Processing 19 of 5376 .mat files.
# Processing 20 of 5376 .mat files.
# Processing 21 of 5376 .mat files.
# Processing 22 of 5376 .mat files.
# Processing 23 of 5376 .mat files.
# Processing 24 of 5376 .mat files.
# Processing 25 of 5376 .mat files.
# Processing 26 of 5376 .mat files.
# Processing 27 of 5376 .mat files.
# Processing 28 of 5376 .mat files.
# Processing 29 of 5376 .mat files.
# Processing 30 of 5376 .mat files.
# Processing 31 of 5376 .mat files.
# Processing 32 of 5376 .mat files.
# Processing 33 of 5376 .mat files.
# Processing 34 of 5376 .mat files.
# Processing 35 of 5376 .mat files.
# Processing 36 of 5376 .mat files.
# Processing 37 of 5376 .mat files.
# Processing 38 of 5376 .mat files.
# Processing 39 of 5376 .mat files.
# Processing 40 of 5376 .mat files.
# Processing 41 of 5376 .mat files.
# Processing 42 of 5376 .mat files.
# Processing 43 of 5376 .mat files.
# Processing 44 of 5376 .mat files.
# Processing 45 of 5376 .mat files.
# Processing 46 of 5376 .mat files.
# Processing 47 of 5376 .mat files.
# Processing 48 of 5376 .mat files.
# Processing 49 of 5376 .mat files.
# Processing 50 of 5376 .mat files.
# Processing 51 of 5376 .mat files.
# Processing 52 of 5376 .mat files.
# Processing 53 of 5376 .mat files.
# Processing 54 of 5376 .mat files.
# Processing 55 of 5376 .mat files.
# Processing 56 of 5376 .mat files.
# Processing 57 of 5376 .mat files.
# Processing 58 of 5376 .mat files.
# Processing 59 of 5376 .mat files.
# Processing 60 of 5376 .mat files.
# Processing 61 of 5376 .mat files.
# Processing 62 of 5376 .mat files.
# Processing 63 of 5376 .mat files.
# Processing 64 of 5376 .mat files.
# Processing 65 of 5376 .mat files.
# Processing 66 of 5376 .mat files.
# Processing 67 of 5376 .mat files.
# Processing 68 of 5376 .mat files.
# Processing 69 of 5376 .mat files.
# Processing 70 of 5376 .mat files.
# Processing 71 of 5376 .mat files.
# Processing 72 of 5376 .mat files.
# Processing 73 of 5376 .mat files.
# Processing 74 of 5376 .mat files.
# Processing 75 of 5376 .mat files.
# Processing 76 of 5376 .mat files.
# Processing 77 of 5376 .mat files.
# Processing 78 of 5376 .mat files.
# Processing 79 of 5376 .mat files.
# Processing 80 of 5376 .mat files.
# Processing 81 of 5376 .mat files.
# Processing 82 of 5376 .mat files.
# Processing 83 of 5376 .mat files.
# Processing 84 of 5376 .mat files.
# Processing 85 of 5376 .mat files.
# Processing 86 of 5376 .mat files.
# Processing 87 of 5376 .mat files.
# Processing 88 of 5376 .mat files.
# Processing 89 of 5376 .mat files.
# Processing 90 of 5376 .mat files.
# Processing 91 of 5376 .mat files.
# Processing 92 of 5376 .mat files.
# Processing 93 of 5376 .mat files.
# Processing 94 of 5376 .mat files.
# Processing 95 of 5376 .mat files.
# Processing 96 of 5376 .mat files.
# Processing 97 of 5376 .mat files.
# Processing 98 of 5376 .mat files.
# Processing 99 of 5376 .mat files.
# Processing 100 of 5376 .mat files.
# Processing 101 of 5376 .mat files.
# Processing 102 of 5376 .mat files.
# Processing 103 of 5376 .mat files.
# Processing 104 of 5376 .mat files.
# Processing 105 of 5376 .mat files.
# Processing 106 of 5376 .mat files.
# Processing 107 of 5376 .mat files.
# Processing 108 of 5376 .mat files.
# Processing 109 of 5376 .mat files.
# Processing 110 of 5376 .mat files.
# Processing 111 of 5376 .mat files.
# Processing 112 of 5376 .mat files.
# Processing 113 of 5376 .mat files.
# Processing 114 of 5376 .mat files.
# Processing 115 of 5376 .mat files.
# Processing 116 of 5376 .mat files.
# Processing 117 of 5376 .mat files.
# Processing 118 of 5376 .mat files.
# Processing 119 of 5376 .mat files.
# Processing 120 of 5376 .mat files.
# Processing 121 of 5376 .mat files.
# Processing 122 of 5376 .mat files.
# Processing 123 of 5376 .mat files.
# Processing 124 of 5376 .mat files.
# Processing 125 of 5376 .mat files.
# Processing 126 of 5376 .mat files.
# Processing 127 of 5376 .mat files.
# Processing 128 of 5376 .mat files.
# Processing 129 of 5376 .mat files.
# Processing 130 of 5376 .mat files.
# Processing 131 of 5376 .mat files.
# Processing 132 of 5376 .mat files.
# Processing 133 of 5376 .mat files.
# Processing 134 of 5376 .mat files.
# Processing 135 of 5376 .mat files.
# Processing 136 of 5376 .mat files.
# Processing 137 of 5376 .mat files.
# Processing 138 of 5376 .mat files.
# Processing 139 of 5376 .mat files.
# Processing 140 of 5376 .mat files.
# Processing 141 of 5376 .mat files.
# Processing 142 of 5376 .mat files.
# Processing 143 of 5376 .mat files.
# Processing 144 of 5376 .mat files.
# Processing 145 of 5376 .mat files.
# Processing 146 of 5376 .mat files.
# Processing 147 of 5376 .mat files.
# Processing 148 of 5376 .mat files.
# Processing 149 of 5376 .mat files.
# Processing 150 of 5376 .mat files.
# Processing 151 of 5376 .mat files.
# Processing 152 of 5376 .mat files.
# Processing 153 of 5376 .mat files.
# Processing 154 of 5376 .mat files.
# Processing 155 of 5376 .mat files.
# Processing 156 of 5376 .mat files.
# Processing 157 of 5376 .mat files.
# Processing 158 of 5376 .mat files.
# Processing 159 of 5376 .mat files.
# Processing 160 of 5376 .mat files.
# Processing 161 of 5376 .mat files.
# Processing 162 of 5376 .mat files.
# Processing 163 of 5376 .mat files.
# Processing 164 of 5376 .mat files.
# Processing 165 of 5376 .mat files.
# Processing 166 of 5376 .mat files.
# Processing 167 of 5376 .mat files.
# Processing 168 of 5376 .mat files.
# Processing 169 of 5376 .mat files.
# Processing 170 of 5376 .mat files.
# Processing 171 of 5376 .mat files.
# Processing 172 of 5376 .mat files.
# Processing 173 of 5376 .mat files.
# Processing 174 of 5376 .mat files.
# Processing 175 of 5376 .mat files.
# Processing 176 of 5376 .mat files.
# Processing 177 of 5376 .mat files.
# Processing 178 of 5376 .mat files.
# Processing 179 of 5376 .mat files.
# Processing 180 of 5376 .mat files.
# Processing 181 of 5376 .mat files.
# Processing 182 of 5376 .mat files.
# Processing 183 of 5376 .mat files.
# Processing 184 of 5376 .mat files.
# Processing 185 of 5376 .mat files.
# Processing 186 of 5376 .mat files.
# Processing 187 of 5376 .mat files.
# Processing 188 of 5376 .mat files.
# Processing 189 of 5376 .mat files.
# Processing 190 of 5376 .mat files.
# Processing 191 of 5376 .mat files.
# Processing 192 of 5376 .mat files.
# Processing 193 of 5376 .mat files.
# Processing 194 of 5376 .mat files.
# Processing 195 of 5376 .mat files.
# Processing 196 of 5376 .mat files.
# Processing 197 of 5376 .mat files.
# Processing 198 of 5376 .mat files.
# Processing 199 of 5376 .mat files.
# Processing 200 of 5376 .mat files.
# Processing 201 of 5376 .mat files.
# Processing 202 of 5376 .mat files.
# Processing 203 of 5376 .mat files.
# Processing 204 of 5376 .mat files.
# Processing 205 of 5376 .mat files.
# Processing 206 of 5376 .mat files.
# Processing 207 of 5376 .mat files.
# Processing 208 of 5376 .mat files.
# Processing 209 of 5376 .mat files.
# Processing 210 of 5376 .mat files.
# Processing 211 of 5376 .mat files.
# Processing 212 of 5376 .mat files.
# Processing 213 of 5376 .mat files.
# Processing 214 of 5376 .mat files.
# Processing 215 of 5376 .mat files.
# Processing 216 of 5376 .mat files.
# Processing 217 of 5376 .mat files.
# Processing 218 of 5376 .mat files.
# Processing 219 of 5376 .mat files.
# Processing 220 of 5376 .mat files.
# Processing 221 of 5376 .mat files.
# Processing 222 of 5376 .mat files.
# Processing 223 of 5376 .mat files.
# Processing 224 of 5376 .mat files.
# Processing 225 of 5376 .mat files.
# Processing 226 of 5376 .mat files.
# Processing 227 of 5376 .mat files.
# Processing 228 of 5376 .mat files.
# Processing 229 of 5376 .mat files.
# Processing 230 of 5376 .mat files.
# Processing 231 of 5376 .mat files.
# Processing 232 of 5376 .mat files.
# Processing 233 of 5376 .mat files.
# Processing 234 of 5376 .mat files.
# Processing 235 of 5376 .mat files.
# Processing 236 of 5376 .mat files.
# Processing 237 of 5376 .mat files.
# Processing 238 of 5376 .mat files.
# Processing 239 of 5376 .mat files.
# Processing 240 of 5376 .mat files.
# Processing 241 of 5376 .mat files.
# Processing 242 of 5376 .mat files.
# Processing 243 of 5376 .mat files.
# Processing 244 of 5376 .mat files.
# Processing 245 of 5376 .mat files.
# Processing 246 of 5376 .mat files.
# Processing 247 of 5376 .mat files.
# Processing 248 of 5376 .mat files.
# Processing 249 of 5376 .mat files.
# Processing 250 of 5376 .mat files.
# Processing 251 of 5376 .mat files.
# Processing 252 of 5376 .mat files.
# Processing 253 of 5376 .mat files.
# Processing 254 of 5376 .mat files.
# Processing 255 of 5376 .mat files.
# Processing 256 of 5376 .mat files.
# Processing 257 of 5376 .mat files.
# Processing 258 of 5376 .mat files.
# Processing 259 of 5376 .mat files.
# Processing 260 of 5376 .mat files.
# Processing 261 of 5376 .mat files.
# Processing 262 of 5376 .mat files.
# Processing 263 of 5376 .mat files.
# Processing 264 of 5376 .mat files.
# Processing 265 of 5376 .mat files.
# Processing 266 of 5376 .mat files.
# Processing 267 of 5376 .mat files.
# Processing 268 of 5376 .mat files.
# Processing 269 of 5376 .mat files.
# Processing 270 of 5376 .mat files.
# Processing 271 of 5376 .mat files.
# Processing 272 of 5376 .mat files.
# Processing 273 of 5376 .mat files.
# Processing 274 of 5376 .mat files.
# Processing 275 of 5376 .mat files.
# Processing 276 of 5376 .mat files.
# Processing 277 of 5376 .mat files.
# Processing 278 of 5376 .mat files.
# Processing 279 of 5376 .mat files.
# Processing 280 of 5376 .mat files.
# Processing 281 of 5376 .mat files.
# Processing 282 of 5376 .mat files.
# Processing 283 of 5376 .mat files.
# Processing 284 of 5376 .mat files.
# Processing 285 of 5376 .mat files.
# Processing 286 of 5376 .mat files.
# Processing 287 of 5376 .mat files.
# Processing 288 of 5376 .mat files.
# Processing 289 of 5376 .mat files.
# Processing 290 of 5376 .mat files.
# Processing 291 of 5376 .mat files.
# Processing 292 of 5376 .mat files.
# Processing 293 of 5376 .mat files.
# Processing 294 of 5376 .mat files.
# Processing 295 of 5376 .mat files.
# Processing 296 of 5376 .mat files.
# Processing 297 of 5376 .mat files.
# Processing 298 of 5376 .mat files.
# Processing 299 of 5376 .mat files.
# Processing 300 of 5376 .mat files.
# Processing 301 of 5376 .mat files.
# Processing 302 of 5376 .mat files.
# Processing 303 of 5376 .mat files.
# Processing 304 of 5376 .mat files.
# Processing 305 of 5376 .mat files.
# Processing 306 of 5376 .mat files.
# Processing 307 of 5376 .mat files.
# Processing 308 of 5376 .mat files.
# Processing 309 of 5376 .mat files.
# Processing 310 of 5376 .mat files.
# Processing 311 of 5376 .mat files.
# Processing 312 of 5376 .mat files.
# Processing 313 of 5376 .mat files.
# Processing 314 of 5376 .mat files.
# Processing 315 of 5376 .mat files.
# Processing 316 of 5376 .mat files.
# Processing 317 of 5376 .mat files.
# Processing 318 of 5376 .mat files.
# Processing 319 of 5376 .mat files.
# Processing 320 of 5376 .mat files.
# Processing 321 of 5376 .mat files.
# Processing 322 of 5376 .mat files.
# Processing 323 of 5376 .mat files.
# Processing 324 of 5376 .mat files.
# Processing 325 of 5376 .mat files.
# Processing 326 of 5376 .mat files.
# Processing 327 of 5376 .mat files.
# Processing 328 of 5376 .mat files.
# Processing 329 of 5376 .mat files.
# Processing 330 of 5376 .mat files.
# Processing 331 of 5376 .mat files.
# Processing 332 of 5376 .mat files.
# Processing 333 of 5376 .mat files.
# Processing 334 of 5376 .mat files.
# Processing 335 of 5376 .mat files.
# Processing 336 of 5376 .mat files.
# Processing 337 of 5376 .mat files.
# Processing 338 of 5376 .mat files.
# Processing 339 of 5376 .mat files.
# Processing 340 of 5376 .mat files.
# Processing 341 of 5376 .mat files.
# Processing 342 of 5376 .mat files.
# Processing 343 of 5376 .mat files.
# Processing 344 of 5376 .mat files.
# Processing 345 of 5376 .mat files.
# Processing 346 of 5376 .mat files.
# Processing 347 of 5376 .mat files.
# Processing 348 of 5376 .mat files.
# Processing 349 of 5376 .mat files.
# Processing 350 of 5376 .mat files.
# Processing 351 of 5376 .mat files.
# Processing 352 of 5376 .mat files.
# Processing 353 of 5376 .mat files.
# Processing 354 of 5376 .mat files.
# Processing 355 of 5376 .mat files.
# Processing 356 of 5376 .mat files.
# Processing 357 of 5376 .mat files.
# Processing 358 of 5376 .mat files.
# Processing 359 of 5376 .mat files.
# Processing 360 of 5376 .mat files.
# Processing 361 of 5376 .mat files.
# Processing 362 of 5376 .mat files.
# Processing 363 of 5376 .mat files.
# Processing 364 of 5376 .mat files.
# Processing 365 of 5376 .mat files.
# Processing 366 of 5376 .mat files.
# Processing 367 of 5376 .mat files.
# Processing 368 of 5376 .mat files.
# Processing 369 of 5376 .mat files.
# Processing 370 of 5376 .mat files.
# Processing 371 of 5376 .mat files.
# Processing 372 of 5376 .mat files.
# Processing 373 of 5376 .mat files.
# Processing 374 of 5376 .mat files.
# Processing 375 of 5376 .mat files.
# Processing 376 of 5376 .mat files.
# Processing 377 of 5376 .mat files.
# Processing 378 of 5376 .mat files.
# Processing 379 of 5376 .mat files.
# Processing 380 of 5376 .mat files.
# Processing 381 of 5376 .mat files.
# Processing 382 of 5376 .mat files.
# Processing 383 of 5376 .mat files.
# Processing 384 of 5376 .mat files.
# Processing 385 of 5376 .mat files.
# Processing 386 of 5376 .mat files.
# Processing 387 of 5376 .mat files.
# Processing 388 of 5376 .mat files.
# Processing 389 of 5376 .mat files.
# Processing 390 of 5376 .mat files.
# Processing 391 of 5376 .mat files.
# Processing 392 of 5376 .mat files.
# Processing 393 of 5376 .mat files.
# Processing 394 of 5376 .mat files.
# Processing 395 of 5376 .mat files.
# Processing 396 of 5376 .mat files.
# Processing 397 of 5376 .mat files.
# Processing 398 of 5376 .mat files.
# Processing 399 of 5376 .mat files.
# Processing 400 of 5376 .mat files.
# Processing 401 of 5376 .mat files.
# Processing 402 of 5376 .mat files.
# Processing 403 of 5376 .mat files.
# Processing 404 of 5376 .mat files.
# Processing 405 of 5376 .mat files.
# Processing 406 of 5376 .mat files.
# Processing 407 of 5376 .mat files.
# Processing 408 of 5376 .mat files.
# Processing 409 of 5376 .mat files.
# Processing 410 of 5376 .mat files.
# Processing 411 of 5376 .mat files.
# Processing 412 of 5376 .mat files.
# Processing 413 of 5376 .mat files.
# Processing 414 of 5376 .mat files.
# Processing 415 of 5376 .mat files.
# Processing 416 of 5376 .mat files.
# Processing 417 of 5376 .mat files.
# Processing 418 of 5376 .mat files.
# Processing 419 of 5376 .mat files.
# Processing 420 of 5376 .mat files.
# Processing 421 of 5376 .mat files.
# Processing 422 of 5376 .mat files.
# Processing 423 of 5376 .mat files.
# Processing 424 of 5376 .mat files.
# Processing 425 of 5376 .mat files.
# Processing 426 of 5376 .mat files.
# Processing 427 of 5376 .mat files.
# Processing 428 of 5376 .mat files.
# Processing 429 of 5376 .mat files.
# Processing 430 of 5376 .mat files.
# Processing 431 of 5376 .mat files.
# Processing 432 of 5376 .mat files.
# Processing 433 of 5376 .mat files.
# Processing 434 of 5376 .mat files.
# Processing 435 of 5376 .mat files.
# Processing 436 of 5376 .mat files.
# Processing 437 of 5376 .mat files.
# Processing 438 of 5376 .mat files.
# Processing 439 of 5376 .mat files.
# Processing 440 of 5376 .mat files.
# Processing 441 of 5376 .mat files.
# Processing 442 of 5376 .mat files.
# Processing 443 of 5376 .mat files.
# Processing 444 of 5376 .mat files.
# Processing 445 of 5376 .mat files.
# Processing 446 of 5376 .mat files.
# Processing 447 of 5376 .mat files.
# Processing 448 of 5376 .mat files.
# Processing 449 of 5376 .mat files.
# Processing 450 of 5376 .mat files.
# Processing 451 of 5376 .mat files.
# Processing 452 of 5376 .mat files.
# Processing 453 of 5376 .mat files.
# Processing 454 of 5376 .mat files.
# Processing 455 of 5376 .mat files.
# Processing 456 of 5376 .mat files.
# Processing 457 of 5376 .mat files.
# Processing 458 of 5376 .mat files.
# Processing 459 of 5376 .mat files.
# Processing 460 of 5376 .mat files.
# Processing 461 of 5376 .mat files.
# Processing 462 of 5376 .mat files.
# Processing 463 of 5376 .mat files.
# Processing 464 of 5376 .mat files.
# Processing 465 of 5376 .mat files.
# Processing 466 of 5376 .mat files.
# Processing 467 of 5376 .mat files.
# Processing 468 of 5376 .mat files.
# Processing 469 of 5376 .mat files.
# Processing 470 of 5376 .mat files.
# Processing 471 of 5376 .mat files.
# Processing 472 of 5376 .mat files.
# Processing 473 of 5376 .mat files.
# Processing 474 of 5376 .mat files.
# Processing 475 of 5376 .mat files.
# Processing 476 of 5376 .mat files.
# Processing 477 of 5376 .mat files.
# Processing 478 of 5376 .mat files.
# Processing 479 of 5376 .mat files.
# Processing 480 of 5376 .mat files.
# Processing 481 of 5376 .mat files.
# Processing 482 of 5376 .mat files.
# Processing 483 of 5376 .mat files.
# Processing 484 of 5376 .mat files.
# Processing 485 of 5376 .mat files.
# Processing 486 of 5376 .mat files.
# Processing 487 of 5376 .mat files.
# Processing 488 of 5376 .mat files.
# Processing 489 of 5376 .mat files.
# Processing 490 of 5376 .mat files.
# Processing 491 of 5376 .mat files.
# Processing 492 of 5376 .mat files.
# Processing 493 of 5376 .mat files.
# Processing 494 of 5376 .mat files.
# Processing 495 of 5376 .mat files.
# Processing 496 of 5376 .mat files.
# Processing 497 of 5376 .mat files.
# Processing 498 of 5376 .mat files.
# Processing 499 of 5376 .mat files.
# Processing 500 of 5376 .mat files.
# Processing 501 of 5376 .mat files.
# Processing 502 of 5376 .mat files.
# Processing 503 of 5376 .mat files.
# Processing 504 of 5376 .mat files.
# Processing 505 of 5376 .mat files.
# Processing 506 of 5376 .mat files.
# Processing 507 of 5376 .mat files.
# Processing 508 of 5376 .mat files.
# Processing 509 of 5376 .mat files.
# Processing 510 of 5376 .mat files.
# Processing 511 of 5376 .mat files.
# Processing 512 of 5376 .mat files.
# Processing 513 of 5376 .mat files.
# Processing 514 of 5376 .mat files.
# Processing 515 of 5376 .mat files.
# Processing 516 of 5376 .mat files.
# Processing 517 of 5376 .mat files.
# Processing 518 of 5376 .mat files.
# Processing 519 of 5376 .mat files.
# Processing 520 of 5376 .mat files.
# Processing 521 of 5376 .mat files.
# Processing 522 of 5376 .mat files.
# Processing 523 of 5376 .mat files.
# Processing 524 of 5376 .mat files.
# Processing 525 of 5376 .mat files.
# Processing 526 of 5376 .mat files.
# Processing 527 of 5376 .mat files.
# Processing 528 of 5376 .mat files.
# Processing 529 of 5376 .mat files.
# Processing 530 of 5376 .mat files.
# Processing 531 of 5376 .mat files.
# Processing 532 of 5376 .mat files.
# Processing 533 of 5376 .mat files.
# Processing 534 of 5376 .mat files.
# Processing 535 of 5376 .mat files.
# Processing 536 of 5376 .mat files.
# Processing 537 of 5376 .mat files.
# Processing 538 of 5376 .mat files.
# Processing 539 of 5376 .mat files.
# Processing 540 of 5376 .mat files.
# Processing 541 of 5376 .mat files.
# Processing 542 of 5376 .mat files.
# Processing 543 of 5376 .mat files.
# Processing 544 of 5376 .mat files.
# Processing 545 of 5376 .mat files.
# Processing 546 of 5376 .mat files.
# Processing 547 of 5376 .mat files.
# Processing 548 of 5376 .mat files.
# Processing 549 of 5376 .mat files.
# Processing 550 of 5376 .mat files.
# Processing 551 of 5376 .mat files.
# Processing 552 of 5376 .mat files.
# Processing 553 of 5376 .mat files.
# Processing 554 of 5376 .mat files.
# Processing 555 of 5376 .mat files.
# Processing 556 of 5376 .mat files.
# Processing 557 of 5376 .mat files.
# Processing 558 of 5376 .mat files.
# Processing 559 of 5376 .mat files.
# Processing 560 of 5376 .mat files.
# Processing 561 of 5376 .mat files.
# Processing 562 of 5376 .mat files.
# Processing 563 of 5376 .mat files.
# Processing 564 of 5376 .mat files.
# Processing 565 of 5376 .mat files.
# Processing 566 of 5376 .mat files.
# Processing 567 of 5376 .mat files.
# Processing 568 of 5376 .mat files.
# Processing 569 of 5376 .mat files.
# Processing 570 of 5376 .mat files.
# Processing 571 of 5376 .mat files.
# Processing 572 of 5376 .mat files.
# Processing 573 of 5376 .mat files.
# Processing 574 of 5376 .mat files.
# Processing 575 of 5376 .mat files.
# Processing 576 of 5376 .mat files.
# Processing 577 of 5376 .mat files.
# Processing 578 of 5376 .mat files.
# Processing 579 of 5376 .mat files.
# Processing 580 of 5376 .mat files.
# Processing 581 of 5376 .mat files.
# Processing 582 of 5376 .mat files.
# Processing 583 of 5376 .mat files.
# Processing 584 of 5376 .mat files.
# Processing 585 of 5376 .mat files.
# Processing 586 of 5376 .mat files.
# Processing 587 of 5376 .mat files.
# Processing 588 of 5376 .mat files.
# Processing 589 of 5376 .mat files.
# Processing 590 of 5376 .mat files.
# Processing 591 of 5376 .mat files.
# Processing 592 of 5376 .mat files.
# Processing 593 of 5376 .mat files.
# Processing 594 of 5376 .mat files.
# Processing 595 of 5376 .mat files.
# Processing 596 of 5376 .mat files.
# Processing 597 of 5376 .mat files.
# Processing 598 of 5376 .mat files.
# Processing 599 of 5376 .mat files.
# Processing 600 of 5376 .mat files.
# Processing 601 of 5376 .mat files.
# Processing 602 of 5376 .mat files.
# Processing 603 of 5376 .mat files.
# Processing 604 of 5376 .mat files.
# Processing 605 of 5376 .mat files.
# Processing 606 of 5376 .mat files.
# Processing 607 of 5376 .mat files.
# Processing 608 of 5376 .mat files.
# Processing 609 of 5376 .mat files.
# Processing 610 of 5376 .mat files.
# Processing 611 of 5376 .mat files.
# Processing 612 of 5376 .mat files.
# Processing 613 of 5376 .mat files.
# Processing 614 of 5376 .mat files.
# Processing 615 of 5376 .mat files.
# Processing 616 of 5376 .mat files.
# Processing 617 of 5376 .mat files.
# Processing 618 of 5376 .mat files.
# Processing 619 of 5376 .mat files.
# Processing 620 of 5376 .mat files.
# Processing 621 of 5376 .mat files.
# Processing 622 of 5376 .mat files.
# Processing 623 of 5376 .mat files.
# Processing 624 of 5376 .mat files.
# Processing 625 of 5376 .mat files.
# Processing 626 of 5376 .mat files.
# Processing 627 of 5376 .mat files.
# Processing 628 of 5376 .mat files.
# Processing 629 of 5376 .mat files.
# Processing 630 of 5376 .mat files.
# Processing 631 of 5376 .mat files.
# Processing 632 of 5376 .mat files.
# Processing 633 of 5376 .mat files.
# Processing 634 of 5376 .mat files.
# Processing 635 of 5376 .mat files.
# Processing 636 of 5376 .mat files.
# Processing 637 of 5376 .mat files.
# Processing 638 of 5376 .mat files.
# Processing 639 of 5376 .mat files.
# Processing 640 of 5376 .mat files.
# Processing 641 of 5376 .mat files.
# Processing 642 of 5376 .mat files.
# Processing 643 of 5376 .mat files.
# Processing 644 of 5376 .mat files.
# Processing 645 of 5376 .mat files.
# Processing 646 of 5376 .mat files.
# Processing 647 of 5376 .mat files.
# Processing 648 of 5376 .mat files.
# Processing 649 of 5376 .mat files.
# Processing 650 of 5376 .mat files.
# Processing 651 of 5376 .mat files.
# Processing 652 of 5376 .mat files.
# Processing 653 of 5376 .mat files.
# Processing 654 of 5376 .mat files.
# Processing 655 of 5376 .mat files.
# Processing 656 of 5376 .mat files.
# Processing 657 of 5376 .mat files.
# Processing 658 of 5376 .mat files.
# Processing 659 of 5376 .mat files.
# Processing 660 of 5376 .mat files.
# Processing 661 of 5376 .mat files.
# Processing 662 of 5376 .mat files.
# Processing 663 of 5376 .mat files.
# Processing 664 of 5376 .mat files.
# Processing 665 of 5376 .mat files.
# Processing 666 of 5376 .mat files.
# Processing 667 of 5376 .mat files.
# Processing 668 of 5376 .mat files.
# Processing 669 of 5376 .mat files.
# Processing 670 of 5376 .mat files.
# Processing 671 of 5376 .mat files.
# Processing 672 of 5376 .mat files.
# Processing 673 of 5376 .mat files.
# Processing 674 of 5376 .mat files.
# Processing 675 of 5376 .mat files.
# Processing 676 of 5376 .mat files.
# Processing 677 of 5376 .mat files.
# Processing 678 of 5376 .mat files.
# Processing 679 of 5376 .mat files.
# Processing 680 of 5376 .mat files.
# Processing 681 of 5376 .mat files.
# Processing 682 of 5376 .mat files.
# Processing 683 of 5376 .mat files.
# Processing 684 of 5376 .mat files.
# Processing 685 of 5376 .mat files.
# Processing 686 of 5376 .mat files.
# Processing 687 of 5376 .mat files.
# Processing 688 of 5376 .mat files.
# Processing 689 of 5376 .mat files.
# Processing 690 of 5376 .mat files.
# Processing 691 of 5376 .mat files.
# Processing 692 of 5376 .mat files.
# Processing 693 of 5376 .mat files.
# Processing 694 of 5376 .mat files.
# Processing 695 of 5376 .mat files.
# Processing 696 of 5376 .mat files.
# Processing 697 of 5376 .mat files.
# Processing 698 of 5376 .mat files.
# Processing 699 of 5376 .mat files.
# Processing 700 of 5376 .mat files.
# Processing 701 of 5376 .mat files.
# Processing 702 of 5376 .mat files.
# Processing 703 of 5376 .mat files.
# Processing 704 of 5376 .mat files.
# Processing 705 of 5376 .mat files.
# Processing 706 of 5376 .mat files.
# Processing 707 of 5376 .mat files.
# Processing 708 of 5376 .mat files.
# Processing 709 of 5376 .mat files.
# Processing 710 of 5376 .mat files.
# Processing 711 of 5376 .mat files.
# Processing 712 of 5376 .mat files.
# Processing 713 of 5376 .mat files.
# Processing 714 of 5376 .mat files.
# Processing 715 of 5376 .mat files.
# Processing 716 of 5376 .mat files.
# Processing 717 of 5376 .mat files.
# Processing 718 of 5376 .mat files.
# Processing 719 of 5376 .mat files.
# Processing 720 of 5376 .mat files.
# Processing 721 of 5376 .mat files.
# Processing 722 of 5376 .mat files.
# Processing 723 of 5376 .mat files.
# Processing 724 of 5376 .mat files.
# Processing 725 of 5376 .mat files.
# Processing 726 of 5376 .mat files.
# Processing 727 of 5376 .mat files.
# Processing 728 of 5376 .mat files.
# Processing 729 of 5376 .mat files.
# Processing 730 of 5376 .mat files.
# Processing 731 of 5376 .mat files.
# Processing 732 of 5376 .mat files.
# Processing 733 of 5376 .mat files.
# Processing 734 of 5376 .mat files.
# Processing 735 of 5376 .mat files.
# Processing 736 of 5376 .mat files.
# Processing 737 of 5376 .mat files.
# Processing 738 of 5376 .mat files.
# Processing 739 of 5376 .mat files.
# Processing 740 of 5376 .mat files.
# Processing 741 of 5376 .mat files.
# Processing 742 of 5376 .mat files.
# Processing 743 of 5376 .mat files.
# Processing 744 of 5376 .mat files.
# Processing 745 of 5376 .mat files.
# Processing 746 of 5376 .mat files.
# Processing 747 of 5376 .mat files.
# Processing 748 of 5376 .mat files.
# Processing 749 of 5376 .mat files.
# Processing 750 of 5376 .mat files.
# Processing 751 of 5376 .mat files.
# Processing 752 of 5376 .mat files.
# Processing 753 of 5376 .mat files.
# Processing 754 of 5376 .mat files.
# Processing 755 of 5376 .mat files.
# Processing 756 of 5376 .mat files.
# Processing 757 of 5376 .mat files.
# Processing 758 of 5376 .mat files.
# Processing 759 of 5376 .mat files.
# Processing 760 of 5376 .mat files.
# Processing 761 of 5376 .mat files.
# Processing 762 of 5376 .mat files.
# Processing 763 of 5376 .mat files.
# Processing 764 of 5376 .mat files.
# Processing 765 of 5376 .mat files.
# Processing 766 of 5376 .mat files.
# Processing 767 of 5376 .mat files.
# Processing 768 of 5376 .mat files.
# Processing 769 of 5376 .mat files.
# Processing 770 of 5376 .mat files.
# Processing 771 of 5376 .mat files.
# Processing 772 of 5376 .mat files.
# Processing 773 of 5376 .mat files.
# Processing 774 of 5376 .mat files.
# Processing 775 of 5376 .mat files.
# Processing 776 of 5376 .mat files.
# Processing 777 of 5376 .mat files.
# Processing 778 of 5376 .mat files.
# Processing 779 of 5376 .mat files.
# Processing 780 of 5376 .mat files.
# Processing 781 of 5376 .mat files.
# Processing 782 of 5376 .mat files.
# Processing 783 of 5376 .mat files.
# Processing 784 of 5376 .mat files.
# Processing 785 of 5376 .mat files.
# Processing 786 of 5376 .mat files.
# Processing 787 of 5376 .mat files.
# Processing 788 of 5376 .mat files.
# Processing 789 of 5376 .mat files.
# Processing 790 of 5376 .mat files.
# Processing 791 of 5376 .mat files.
# Processing 792 of 5376 .mat files.
# Processing 793 of 5376 .mat files.
# Processing 794 of 5376 .mat files.
# Processing 795 of 5376 .mat files.
# Processing 796 of 5376 .mat files.
# Processing 797 of 5376 .mat files.
# Processing 798 of 5376 .mat files.
# Processing 799 of 5376 .mat files.
# Processing 800 of 5376 .mat files.
# Processing 801 of 5376 .mat files.
# Processing 802 of 5376 .mat files.
# Processing 803 of 5376 .mat files.
# Processing 804 of 5376 .mat files.
# Processing 805 of 5376 .mat files.
# Processing 806 of 5376 .mat files.
# Processing 807 of 5376 .mat files.
# Processing 808 of 5376 .mat files.
# Processing 809 of 5376 .mat files.
# Processing 810 of 5376 .mat files.
# Processing 811 of 5376 .mat files.
# Processing 812 of 5376 .mat files.
# Processing 813 of 5376 .mat files.
# Processing 814 of 5376 .mat files.
# Processing 815 of 5376 .mat files.
# Processing 816 of 5376 .mat files.
# Processing 817 of 5376 .mat files.
# Processing 818 of 5376 .mat files.
# Processing 819 of 5376 .mat files.
# Processing 820 of 5376 .mat files.
# Processing 821 of 5376 .mat files.
# Processing 822 of 5376 .mat files.
# Processing 823 of 5376 .mat files.
# Processing 824 of 5376 .mat files.
# Processing 825 of 5376 .mat files.
# Processing 826 of 5376 .mat files.
# Processing 827 of 5376 .mat files.
# Processing 828 of 5376 .mat files.
# Processing 829 of 5376 .mat files.
# Processing 830 of 5376 .mat files.
# Processing 831 of 5376 .mat files.
# Processing 832 of 5376 .mat files.
# Processing 833 of 5376 .mat files.
# Processing 834 of 5376 .mat files.
# Processing 835 of 5376 .mat files.
# Processing 836 of 5376 .mat files.
# Processing 837 of 5376 .mat files.
# Processing 838 of 5376 .mat files.
# Processing 839 of 5376 .mat files.
# Processing 840 of 5376 .mat files.
# Processing 841 of 5376 .mat files.
# Processing 842 of 5376 .mat files.
# Processing 843 of 5376 .mat files.
# Processing 844 of 5376 .mat files.
# Processing 845 of 5376 .mat files.
# Processing 846 of 5376 .mat files.
# Processing 847 of 5376 .mat files.
# Processing 848 of 5376 .mat files.
# Processing 849 of 5376 .mat files.
# Processing 850 of 5376 .mat files.
# Processing 851 of 5376 .mat files.
# Processing 852 of 5376 .mat files.
# Processing 853 of 5376 .mat files.
# Processing 854 of 5376 .mat files.
# Processing 855 of 5376 .mat files.
# Processing 856 of 5376 .mat files.
# Processing 857 of 5376 .mat files.
# Processing 858 of 5376 .mat files.
# Processing 859 of 5376 .mat files.
# Processing 860 of 5376 .mat files.
# Processing 861 of 5376 .mat files.
# Processing 862 of 5376 .mat files.
# Processing 863 of 5376 .mat files.
# Processing 864 of 5376 .mat files.
# Processing 865 of 5376 .mat files.
# Processing 866 of 5376 .mat files.
# Processing 867 of 5376 .mat files.
# Processing 868 of 5376 .mat files.
# Processing 869 of 5376 .mat files.
# Processing 870 of 5376 .mat files.
# Processing 871 of 5376 .mat files.
# Processing 872 of 5376 .mat files.
# Processing 873 of 5376 .mat files.
# Processing 874 of 5376 .mat files.
# Processing 875 of 5376 .mat files.
# Processing 876 of 5376 .mat files.
# Processing 877 of 5376 .mat files.
# Processing 878 of 5376 .mat files.
# Processing 879 of 5376 .mat files.
# Processing 880 of 5376 .mat files.
# Processing 881 of 5376 .mat files.
# Processing 882 of 5376 .mat files.
# Processing 883 of 5376 .mat files.
# Processing 884 of 5376 .mat files.
# Processing 885 of 5376 .mat files.
# Processing 886 of 5376 .mat files.
# Processing 887 of 5376 .mat files.
# Processing 888 of 5376 .mat files.
# Processing 889 of 5376 .mat files.
# Processing 890 of 5376 .mat files.
# Processing 891 of 5376 .mat files.
# Processing 892 of 5376 .mat files.
# Processing 893 of 5376 .mat files.
# Processing 894 of 5376 .mat files.
# Processing 895 of 5376 .mat files.
# Processing 896 of 5376 .mat files.
# Processing 897 of 5376 .mat files.
# Processing 898 of 5376 .mat files.
# Processing 899 of 5376 .mat files.
# Processing 900 of 5376 .mat files.
# Processing 901 of 5376 .mat files.
# Processing 902 of 5376 .mat files.
# Processing 903 of 5376 .mat files.
# Processing 904 of 5376 .mat files.
# Processing 905 of 5376 .mat files.
# Processing 906 of 5376 .mat files.
# Processing 907 of 5376 .mat files.
# Processing 908 of 5376 .mat files.
# Processing 909 of 5376 .mat files.
# Processing 910 of 5376 .mat files.
# Processing 911 of 5376 .mat files.
# Processing 912 of 5376 .mat files.
# Processing 913 of 5376 .mat files.
# Processing 914 of 5376 .mat files.
# Processing 915 of 5376 .mat files.
# Processing 916 of 5376 .mat files.
# Processing 917 of 5376 .mat files.
# Processing 918 of 5376 .mat files.
# Processing 919 of 5376 .mat files.
# Processing 920 of 5376 .mat files.
# Processing 921 of 5376 .mat files.
# Processing 922 of 5376 .mat files.
# Processing 923 of 5376 .mat files.
# Processing 924 of 5376 .mat files.
# Processing 925 of 5376 .mat files.
# Processing 926 of 5376 .mat files.
# Processing 927 of 5376 .mat files.
# Processing 928 of 5376 .mat files.
# Processing 929 of 5376 .mat files.
# Processing 930 of 5376 .mat files.
# Processing 931 of 5376 .mat files.
# Processing 932 of 5376 .mat files.
# Processing 933 of 5376 .mat files.
# Processing 934 of 5376 .mat files.
# Processing 935 of 5376 .mat files.
# Processing 936 of 5376 .mat files.
# Processing 937 of 5376 .mat files.
# Processing 938 of 5376 .mat files.
# Processing 939 of 5376 .mat files.
# Processing 940 of 5376 .mat files.
# Processing 941 of 5376 .mat files.
# Processing 942 of 5376 .mat files.
# Processing 943 of 5376 .mat files.
# Processing 944 of 5376 .mat files.
# Processing 945 of 5376 .mat files.
# Processing 946 of 5376 .mat files.
# Processing 947 of 5376 .mat files.
# Processing 948 of 5376 .mat files.
# Processing 949 of 5376 .mat files.
# Processing 950 of 5376 .mat files.
# Processing 951 of 5376 .mat files.
# Processing 952 of 5376 .mat files.
# Processing 953 of 5376 .mat files.
# Processing 954 of 5376 .mat files.
# Processing 955 of 5376 .mat files.
# Processing 956 of 5376 .mat files.
# Processing 957 of 5376 .mat files.
# Processing 958 of 5376 .mat files.
# Processing 959 of 5376 .mat files.
# Processing 960 of 5376 .mat files.
# Processing 961 of 5376 .mat files.
# Processing 962 of 5376 .mat files.
# Processing 963 of 5376 .mat files.
# Processing 964 of 5376 .mat files.
# Processing 965 of 5376 .mat files.
# Processing 966 of 5376 .mat files.
# Processing 967 of 5376 .mat files.
# Processing 968 of 5376 .mat files.
# Processing 969 of 5376 .mat files.
# Processing 970 of 5376 .mat files.
# Processing 971 of 5376 .mat files.
# Processing 972 of 5376 .mat files.
# Processing 973 of 5376 .mat files.
# Processing 974 of 5376 .mat files.
# Processing 975 of 5376 .mat files.
# Processing 976 of 5376 .mat files.
# Processing 977 of 5376 .mat files.
# Processing 978 of 5376 .mat files.
# Processing 979 of 5376 .mat files.
# Processing 980 of 5376 .mat files.
# Processing 981 of 5376 .mat files.
# Processing 982 of 5376 .mat files.
# Processing 983 of 5376 .mat files.
# Processing 984 of 5376 .mat files.
# Processing 985 of 5376 .mat files.
# Processing 986 of 5376 .mat files.
# Processing 987 of 5376 .mat files.
# Processing 988 of 5376 .mat files.
# Processing 989 of 5376 .mat files.
# Processing 990 of 5376 .mat files.
# Processing 991 of 5376 .mat files.
# Processing 992 of 5376 .mat files.
# Processing 993 of 5376 .mat files.
# Processing 994 of 5376 .mat files.
# Processing 995 of 5376 .mat files.
# Processing 996 of 5376 .mat files.
# Processing 997 of 5376 .mat files.
# Processing 998 of 5376 .mat files.
# Processing 999 of 5376 .mat files.
# Processing 1000 of 5376 .mat files.
# Processing 1001 of 5376 .mat files.
# Processing 1002 of 5376 .mat files.
# Processing 1003 of 5376 .mat files.
# Processing 1004 of 5376 .mat files.
# Processing 1005 of 5376 .mat files.
# Processing 1006 of 5376 .mat files.
# Processing 1007 of 5376 .mat files.
# Processing 1008 of 5376 .mat files.
# Processing 1009 of 5376 .mat files.
# Processing 1010 of 5376 .mat files.
# Processing 1011 of 5376 .mat files.
# Processing 1012 of 5376 .mat files.
# Processing 1013 of 5376 .mat files.
# Processing 1014 of 5376 .mat files.
# Processing 1015 of 5376 .mat files.
# Processing 1016 of 5376 .mat files.
# Processing 1017 of 5376 .mat files.
# Processing 1018 of 5376 .mat files.
# Processing 1019 of 5376 .mat files.
# Processing 1020 of 5376 .mat files.
# Processing 1021 of 5376 .mat files.
# Processing 1022 of 5376 .mat files.
# Processing 1023 of 5376 .mat files.
# Processing 1024 of 5376 .mat files.
# Processing 1025 of 5376 .mat files.
# Processing 1026 of 5376 .mat files.
# Processing 1027 of 5376 .mat files.
# Processing 1028 of 5376 .mat files.
# Processing 1029 of 5376 .mat files.
# Processing 1030 of 5376 .mat files.
# Processing 1031 of 5376 .mat files.
# Processing 1032 of 5376 .mat files.
# Processing 1033 of 5376 .mat files.
# Processing 1034 of 5376 .mat files.
# Processing 1035 of 5376 .mat files.
# Processing 1036 of 5376 .mat files.
# Processing 1037 of 5376 .mat files.
# Processing 1038 of 5376 .mat files.
# Processing 1039 of 5376 .mat files.
# Processing 1040 of 5376 .mat files.
# Processing 1041 of 5376 .mat files.
# Processing 1042 of 5376 .mat files.
# Processing 1043 of 5376 .mat files.
# Processing 1044 of 5376 .mat files.
# Processing 1045 of 5376 .mat files.
# Processing 1046 of 5376 .mat files.
# Processing 1047 of 5376 .mat files.
# Processing 1048 of 5376 .mat files.
# Processing 1049 of 5376 .mat files.
# Processing 1050 of 5376 .mat files.
# Processing 1051 of 5376 .mat files.
# Processing 1052 of 5376 .mat files.
# Processing 1053 of 5376 .mat files.
# Processing 1054 of 5376 .mat files.
# Processing 1055 of 5376 .mat files.
# Processing 1056 of 5376 .mat files.
# Processing 1057 of 5376 .mat files.
# Processing 1058 of 5376 .mat files.
# Processing 1059 of 5376 .mat files.
# Processing 1060 of 5376 .mat files.
# Processing 1061 of 5376 .mat files.
# Processing 1062 of 5376 .mat files.
# Processing 1063 of 5376 .mat files.
# Processing 1064 of 5376 .mat files.
# Processing 1065 of 5376 .mat files.
# Processing 1066 of 5376 .mat files.
# Processing 1067 of 5376 .mat files.
# Processing 1068 of 5376 .mat files.
# Processing 1069 of 5376 .mat files.
# Processing 1070 of 5376 .mat files.
# Processing 1071 of 5376 .mat files.
# Processing 1072 of 5376 .mat files.
# Processing 1073 of 5376 .mat files.
# Processing 1074 of 5376 .mat files.
# Processing 1075 of 5376 .mat files.
# Processing 1076 of 5376 .mat files.
# Processing 1077 of 5376 .mat files.
# Processing 1078 of 5376 .mat files.
# Processing 1079 of 5376 .mat files.
# Processing 1080 of 5376 .mat files.
# Processing 1081 of 5376 .mat files.
# Processing 1082 of 5376 .mat files.
# Processing 1083 of 5376 .mat files.
# Processing 1084 of 5376 .mat files.
# Processing 1085 of 5376 .mat files.
# Processing 1086 of 5376 .mat files.
# Processing 1087 of 5376 .mat files.
# Processing 1088 of 5376 .mat files.
# Processing 1089 of 5376 .mat files.
# Processing 1090 of 5376 .mat files.
# Processing 1091 of 5376 .mat files.
# Processing 1092 of 5376 .mat files.
# Processing 1093 of 5376 .mat files.
# Processing 1094 of 5376 .mat files.
# Processing 1095 of 5376 .mat files.
# Processing 1096 of 5376 .mat files.
# Processing 1097 of 5376 .mat files.
# Processing 1098 of 5376 .mat files.
# Processing 1099 of 5376 .mat files.
# Processing 1100 of 5376 .mat files.
# Processing 1101 of 5376 .mat files.
# Processing 1102 of 5376 .mat files.
# Processing 1103 of 5376 .mat files.
# Processing 1104 of 5376 .mat files.
# Processing 1105 of 5376 .mat files.
# Processing 1106 of 5376 .mat files.
# Processing 1107 of 5376 .mat files.
# Processing 1108 of 5376 .mat files.
# Processing 1109 of 5376 .mat files.
# Processing 1110 of 5376 .mat files.
# Processing 1111 of 5376 .mat files.
# Processing 1112 of 5376 .mat files.
# Processing 1113 of 5376 .mat files.
# Processing 1114 of 5376 .mat files.
# Processing 1115 of 5376 .mat files.
# Processing 1116 of 5376 .mat files.
# Processing 1117 of 5376 .mat files.
# Processing 1118 of 5376 .mat files.
# Processing 1119 of 5376 .mat files.
# Processing 1120 of 5376 .mat files.
# Processing 1121 of 5376 .mat files.
# Processing 1122 of 5376 .mat files.
# Processing 1123 of 5376 .mat files.
# Processing 1124 of 5376 .mat files.
# Processing 1125 of 5376 .mat files.
# Processing 1126 of 5376 .mat files.
# Processing 1127 of 5376 .mat files.
# Processing 1128 of 5376 .mat files.
# Processing 1129 of 5376 .mat files.
# Processing 1130 of 5376 .mat files.
# Processing 1131 of 5376 .mat files.
# Processing 1132 of 5376 .mat files.
# Processing 1133 of 5376 .mat files.
# Processing 1134 of 5376 .mat files.
# Processing 1135 of 5376 .mat files.
# Processing 1136 of 5376 .mat files.
# Processing 1137 of 5376 .mat files.
# Processing 1138 of 5376 .mat files.
# Processing 1139 of 5376 .mat files.
# Processing 1140 of 5376 .mat files.
# Processing 1141 of 5376 .mat files.
# Processing 1142 of 5376 .mat files.
# Processing 1143 of 5376 .mat files.
# Processing 1144 of 5376 .mat files.
# Processing 1145 of 5376 .mat files.
# Processing 1146 of 5376 .mat files.
# Processing 1147 of 5376 .mat files.
# Processing 1148 of 5376 .mat files.
# Processing 1149 of 5376 .mat files.
# Processing 1150 of 5376 .mat files.
# Processing 1151 of 5376 .mat files.
# Processing 1152 of 5376 .mat files.
# Processing 1153 of 5376 .mat files.
# Processing 1154 of 5376 .mat files.
# Processing 1155 of 5376 .mat files.
# Processing 1156 of 5376 .mat files.
# Processing 1157 of 5376 .mat files.
# Processing 1158 of 5376 .mat files.
# Processing 1159 of 5376 .mat files.
# Processing 1160 of 5376 .mat files.
# Processing 1161 of 5376 .mat files.
# Processing 1162 of 5376 .mat files.
# Processing 1163 of 5376 .mat files.
# Processing 1164 of 5376 .mat files.
# Processing 1165 of 5376 .mat files.
# Processing 1166 of 5376 .mat files.
# Processing 1167 of 5376 .mat files.
# Processing 1168 of 5376 .mat files.
# Processing 1169 of 5376 .mat files.
# Processing 1170 of 5376 .mat files.
# Processing 1171 of 5376 .mat files.
# Processing 1172 of 5376 .mat files.
# Processing 1173 of 5376 .mat files.
# Processing 1174 of 5376 .mat files.
# Processing 1175 of 5376 .mat files.
# Processing 1176 of 5376 .mat files.
# Processing 1177 of 5376 .mat files.
# Processing 1178 of 5376 .mat files.
# Processing 1179 of 5376 .mat files.
# Processing 1180 of 5376 .mat files.
# Processing 1181 of 5376 .mat files.
# Processing 1182 of 5376 .mat files.
# Processing 1183 of 5376 .mat files.
# Processing 1184 of 5376 .mat files.
# Processing 1185 of 5376 .mat files.
# Processing 1186 of 5376 .mat files.
# Processing 1187 of 5376 .mat files.
# Processing 1188 of 5376 .mat files.
# Processing 1189 of 5376 .mat files.
# Processing 1190 of 5376 .mat files.
# Processing 1191 of 5376 .mat files.
# Processing 1192 of 5376 .mat files.
# Processing 1193 of 5376 .mat files.
# Processing 1194 of 5376 .mat files.
# Processing 1195 of 5376 .mat files.
# Processing 1196 of 5376 .mat files.
# Processing 1197 of 5376 .mat files.
# Processing 1198 of 5376 .mat files.
# Processing 1199 of 5376 .mat files.
# Processing 1200 of 5376 .mat files.
# Processing 1201 of 5376 .mat files.
# Processing 1202 of 5376 .mat files.
# Processing 1203 of 5376 .mat files.
# Processing 1204 of 5376 .mat files.
# Processing 1205 of 5376 .mat files.
# Processing 1206 of 5376 .mat files.
# Processing 1207 of 5376 .mat files.
# Processing 1208 of 5376 .mat files.
# Processing 1209 of 5376 .mat files.
# Processing 1210 of 5376 .mat files.
# Processing 1211 of 5376 .mat files.
# Processing 1212 of 5376 .mat files.
# Processing 1213 of 5376 .mat files.
# Processing 1214 of 5376 .mat files.
# Processing 1215 of 5376 .mat files.
# Processing 1216 of 5376 .mat files.
# Processing 1217 of 5376 .mat files.
# Processing 1218 of 5376 .mat files.
# Processing 1219 of 5376 .mat files.
# Processing 1220 of 5376 .mat files.
# Processing 1221 of 5376 .mat files.
# Processing 1222 of 5376 .mat files.
# Processing 1223 of 5376 .mat files.
# Processing 1224 of 5376 .mat files.
# Processing 1225 of 5376 .mat files.
# Processing 1226 of 5376 .mat files.
# Processing 1227 of 5376 .mat files.
# Processing 1228 of 5376 .mat files.
# Processing 1229 of 5376 .mat files.
# Processing 1230 of 5376 .mat files.
# Processing 1231 of 5376 .mat files.
# Processing 1232 of 5376 .mat files.
# Processing 1233 of 5376 .mat files.
# Processing 1234 of 5376 .mat files.
# Processing 1235 of 5376 .mat files.
# Processing 1236 of 5376 .mat files.
# Processing 1237 of 5376 .mat files.
# Processing 1238 of 5376 .mat files.
# Processing 1239 of 5376 .mat files.
# Processing 1240 of 5376 .mat files.
# Processing 1241 of 5376 .mat files.
# Processing 1242 of 5376 .mat files.
# Processing 1243 of 5376 .mat files.
# Processing 1244 of 5376 .mat files.
# Processing 1245 of 5376 .mat files.
# Processing 1246 of 5376 .mat files.
# Processing 1247 of 5376 .mat files.
# Processing 1248 of 5376 .mat files.
# Processing 1249 of 5376 .mat files.
# Processing 1250 of 5376 .mat files.
# Processing 1251 of 5376 .mat files.
# Processing 1252 of 5376 .mat files.
# Processing 1253 of 5376 .mat files.
# Processing 1254 of 5376 .mat files.
# Processing 1255 of 5376 .mat files.
# Processing 1256 of 5376 .mat files.
# Processing 1257 of 5376 .mat files.
# Processing 1258 of 5376 .mat files.
# Processing 1259 of 5376 .mat files.
# Processing 1260 of 5376 .mat files.
# Processing 1261 of 5376 .mat files.
# Processing 1262 of 5376 .mat files.
# Processing 1263 of 5376 .mat files.
# Processing 1264 of 5376 .mat files.
# Processing 1265 of 5376 .mat files.
# Processing 1266 of 5376 .mat files.
# Processing 1267 of 5376 .mat files.
# Processing 1268 of 5376 .mat files.
# Processing 1269 of 5376 .mat files.
# Processing 1270 of 5376 .mat files.
# Processing 1271 of 5376 .mat files.
# Processing 1272 of 5376 .mat files.
# Processing 1273 of 5376 .mat files.
# Processing 1274 of 5376 .mat files.
# Processing 1275 of 5376 .mat files.
# Processing 1276 of 5376 .mat files.
# Processing 1277 of 5376 .mat files.
# Processing 1278 of 5376 .mat files.
# Processing 1279 of 5376 .mat files.
# Processing 1280 of 5376 .mat files.
# Processing 1281 of 5376 .mat files.
# Processing 1282 of 5376 .mat files.
# Processing 1283 of 5376 .mat files.
# Processing 1284 of 5376 .mat files.
# Processing 1285 of 5376 .mat files.
# Processing 1286 of 5376 .mat files.
# Processing 1287 of 5376 .mat files.
# Processing 1288 of 5376 .mat files.
# Processing 1289 of 5376 .mat files.
# Processing 1290 of 5376 .mat files.
# Processing 1291 of 5376 .mat files.
# Processing 1292 of 5376 .mat files.
# Processing 1293 of 5376 .mat files.
# Processing 1294 of 5376 .mat files.
# Processing 1295 of 5376 .mat files.
# Processing 1296 of 5376 .mat files.
# Processing 1297 of 5376 .mat files.
# Processing 1298 of 5376 .mat files.
# Processing 1299 of 5376 .mat files.
# Processing 1300 of 5376 .mat files.
# Processing 1301 of 5376 .mat files.
# Processing 1302 of 5376 .mat files.
# Processing 1303 of 5376 .mat files.
# Processing 1304 of 5376 .mat files.
# Processing 1305 of 5376 .mat files.
# Processing 1306 of 5376 .mat files.
# Processing 1307 of 5376 .mat files.
# Processing 1308 of 5376 .mat files.
# Processing 1309 of 5376 .mat files.
# Processing 1310 of 5376 .mat files.
# Processing 1311 of 5376 .mat files.
# Processing 1312 of 5376 .mat files.
# Processing 1313 of 5376 .mat files.
# Processing 1314 of 5376 .mat files.
# Processing 1315 of 5376 .mat files.
# Processing 1316 of 5376 .mat files.
# Processing 1317 of 5376 .mat files.
# Processing 1318 of 5376 .mat files.
# Processing 1319 of 5376 .mat files.
# Processing 1320 of 5376 .mat files.
# Processing 1321 of 5376 .mat files.
# Processing 1322 of 5376 .mat files.
# Processing 1323 of 5376 .mat files.
# Processing 1324 of 5376 .mat files.
# Processing 1325 of 5376 .mat files.
# Processing 1326 of 5376 .mat files.
# Processing 1327 of 5376 .mat files.
# Processing 1328 of 5376 .mat files.
# Processing 1329 of 5376 .mat files.
# Processing 1330 of 5376 .mat files.
# Processing 1331 of 5376 .mat files.
# Processing 1332 of 5376 .mat files.
# Processing 1333 of 5376 .mat files.
# Processing 1334 of 5376 .mat files.
# Processing 1335 of 5376 .mat files.
# Processing 1336 of 5376 .mat files.
# Processing 1337 of 5376 .mat files.
# Processing 1338 of 5376 .mat files.
# Processing 1339 of 5376 .mat files.
# Processing 1340 of 5376 .mat files.
# Processing 1341 of 5376 .mat files.
# Processing 1342 of 5376 .mat files.
# Processing 1343 of 5376 .mat files.
# Processing 1344 of 5376 .mat files.
# Processing 1345 of 5376 .mat files.
# Processing 1346 of 5376 .mat files.
# Processing 1347 of 5376 .mat files.
# Processing 1348 of 5376 .mat files.
# Processing 1349 of 5376 .mat files.
# Processing 1350 of 5376 .mat files.
# Processing 1351 of 5376 .mat files.
# Processing 1352 of 5376 .mat files.
# Processing 1353 of 5376 .mat files.
# Processing 1354 of 5376 .mat files.
# Processing 1355 of 5376 .mat files.
# Processing 1356 of 5376 .mat files.
# Processing 1357 of 5376 .mat files.
# Processing 1358 of 5376 .mat files.
# Processing 1359 of 5376 .mat files.
# Processing 1360 of 5376 .mat files.
# Processing 1361 of 5376 .mat files.
# Processing 1362 of 5376 .mat files.
# Processing 1363 of 5376 .mat files.
# Processing 1364 of 5376 .mat files.
# Processing 1365 of 5376 .mat files.
# Processing 1366 of 5376 .mat files.
# Processing 1367 of 5376 .mat files.
# Processing 1368 of 5376 .mat files.
# Processing 1369 of 5376 .mat files.
# Processing 1370 of 5376 .mat files.
# Processing 1371 of 5376 .mat files.
# Processing 1372 of 5376 .mat files.
# Processing 1373 of 5376 .mat files.
# Processing 1374 of 5376 .mat files.
# Processing 1375 of 5376 .mat files.
# Processing 1376 of 5376 .mat files.
# Processing 1377 of 5376 .mat files.
# Processing 1378 of 5376 .mat files.
# Processing 1379 of 5376 .mat files.
# Processing 1380 of 5376 .mat files.
# Processing 1381 of 5376 .mat files.
# Processing 1382 of 5376 .mat files.
# Processing 1383 of 5376 .mat files.
# Processing 1384 of 5376 .mat files.
# Processing 1385 of 5376 .mat files.
# Processing 1386 of 5376 .mat files.
# Processing 1387 of 5376 .mat files.
# Processing 1388 of 5376 .mat files.
# Processing 1389 of 5376 .mat files.
# Processing 1390 of 5376 .mat files.
# Processing 1391 of 5376 .mat files.
# Processing 1392 of 5376 .mat files.
# Processing 1393 of 5376 .mat files.
# Processing 1394 of 5376 .mat files.
# Processing 1395 of 5376 .mat files.
# Processing 1396 of 5376 .mat files.
# Processing 1397 of 5376 .mat files.
# Processing 1398 of 5376 .mat files.
# Processing 1399 of 5376 .mat files.
# Processing 1400 of 5376 .mat files.
# Processing 1401 of 5376 .mat files.
# Processing 1402 of 5376 .mat files.
# Processing 1403 of 5376 .mat files.
# Processing 1404 of 5376 .mat files.
# Processing 1405 of 5376 .mat files.
# Processing 1406 of 5376 .mat files.
# Processing 1407 of 5376 .mat files.
# Processing 1408 of 5376 .mat files.
# Processing 1409 of 5376 .mat files.
# Processing 1410 of 5376 .mat files.
# Processing 1411 of 5376 .mat files.
# Processing 1412 of 5376 .mat files.
# Processing 1413 of 5376 .mat files.
# Processing 1414 of 5376 .mat files.
# Processing 1415 of 5376 .mat files.
# Processing 1416 of 5376 .mat files.
# Processing 1417 of 5376 .mat files.
# Processing 1418 of 5376 .mat files.
# Processing 1419 of 5376 .mat files.
# Processing 1420 of 5376 .mat files.
# Processing 1421 of 5376 .mat files.
# Processing 1422 of 5376 .mat files.
# Processing 1423 of 5376 .mat files.
# Processing 1424 of 5376 .mat files.
# Processing 1425 of 5376 .mat files.
# Processing 1426 of 5376 .mat files.
# Processing 1427 of 5376 .mat files.
# Processing 1428 of 5376 .mat files.
# Processing 1429 of 5376 .mat files.
# Processing 1430 of 5376 .mat files.
# Processing 1431 of 5376 .mat files.
# Processing 1432 of 5376 .mat files.
# Processing 1433 of 5376 .mat files.
# Processing 1434 of 5376 .mat files.
# Processing 1435 of 5376 .mat files.
# Processing 1436 of 5376 .mat files.
# Processing 1437 of 5376 .mat files.
# Processing 1438 of 5376 .mat files.
# Processing 1439 of 5376 .mat files.
# Processing 1440 of 5376 .mat files.
# Processing 1441 of 5376 .mat files.
# Processing 1442 of 5376 .mat files.
# Processing 1443 of 5376 .mat files.
# Processing 1444 of 5376 .mat files.
# Processing 1445 of 5376 .mat files.
# Processing 1446 of 5376 .mat files.
# Processing 1447 of 5376 .mat files.
# Processing 1448 of 5376 .mat files.
# Processing 1449 of 5376 .mat files.
# Processing 1450 of 5376 .mat files.
# Processing 1451 of 5376 .mat files.
# Processing 1452 of 5376 .mat files.
# Processing 1453 of 5376 .mat files.
# Processing 1454 of 5376 .mat files.
# Processing 1455 of 5376 .mat files.
# Processing 1456 of 5376 .mat files.
# Processing 1457 of 5376 .mat files.
# Processing 1458 of 5376 .mat files.
# Processing 1459 of 5376 .mat files.
# Processing 1460 of 5376 .mat files.
# Processing 1461 of 5376 .mat files.
# Processing 1462 of 5376 .mat files.
# Processing 1463 of 5376 .mat files.
# Processing 1464 of 5376 .mat files.
# Processing 1465 of 5376 .mat files.
# Processing 1466 of 5376 .mat files.
# Processing 1467 of 5376 .mat files.
# Processing 1468 of 5376 .mat files.
# Processing 1469 of 5376 .mat files.
# Processing 1470 of 5376 .mat files.
# Processing 1471 of 5376 .mat files.
# Processing 1472 of 5376 .mat files.
# Processing 1473 of 5376 .mat files.
# Processing 1474 of 5376 .mat files.
# Processing 1475 of 5376 .mat files.
# Processing 1476 of 5376 .mat files.
# Processing 1477 of 5376 .mat files.
# Processing 1478 of 5376 .mat files.
# Processing 1479 of 5376 .mat files.
# Processing 1480 of 5376 .mat files.
# Processing 1481 of 5376 .mat files.
# Processing 1482 of 5376 .mat files.
# Processing 1483 of 5376 .mat files.
# Processing 1484 of 5376 .mat files.
# Processing 1485 of 5376 .mat files.
# Processing 1486 of 5376 .mat files.
# Processing 1487 of 5376 .mat files.
# Processing 1488 of 5376 .mat files.
# Processing 1489 of 5376 .mat files.
# Processing 1490 of 5376 .mat files.
# Processing 1491 of 5376 .mat files.
# Processing 1492 of 5376 .mat files.
# Processing 1493 of 5376 .mat files.
# Processing 1494 of 5376 .mat files.
# Processing 1495 of 5376 .mat files.
# Processing 1496 of 5376 .mat files.
# Processing 1497 of 5376 .mat files.
# Processing 1498 of 5376 .mat files.
# Processing 1499 of 5376 .mat files.
# Processing 1500 of 5376 .mat files.
# Processing 1501 of 5376 .mat files.
# Processing 1502 of 5376 .mat files.
# Processing 1503 of 5376 .mat files.
# Processing 1504 of 5376 .mat files.
# Processing 1505 of 5376 .mat files.
# Processing 1506 of 5376 .mat files.
# Processing 1507 of 5376 .mat files.
# Processing 1508 of 5376 .mat files.
# Processing 1509 of 5376 .mat files.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <module>
#      11 dl_data = DASHlinkData(mat_file)
#      12 if dl_data.contains_phase_no(phase=PHASE_NO):
# ---> 13     if dl_data.lands_at_airport(airport_lat_lon=MSP_AIRPORT_LAT_LON):
#      14         for key in key_list_25:
#      15             dl_data.temporal_resample_to_4_seconds(key)
#
# File ~/para-atm-collection/safety-risk-uq/touchdown-vertical-speed-bnn/dataUtils.py:98, in DASHlinkData.lands_at_airport(self, airport_lat_lon, key_list)
#      95     self.temporal_resample_to_1_second(key)
#      96 td_index = self.get_touchdown_index()
# ---> 98 tem_lat = self.resampled_data_1s['LATP'][td_index]
#      99 tem_lon = self.resampled_data_1s['LONP'][td_index]
#     100 pos=(tem_lat,tem_lon)
#
# File ~/anaconda3/envs/paraatm/lib/python3.8/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/anaconda3/envs/paraatm/lib/python3.8/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/anaconda3/envs/paraatm/lib/python3.8/site-packages/pandas/core/indexes/range.py:389, in RangeIndex.get_loc(self, key, method, tolerance)
#     387             raise KeyError(key) from err
#     388     self._check_indexing_error(key)
# --> 389     raise KeyError(key)
#     390 return super().get_loc(key, method=method, tolerance=tolerance)
#
# KeyError: nan

# %%
print("Number of Files with Landing Aircraft: {} out of {}.".format(len(dfs),len(downloaded_mat_files)))
# Out:
# Number of Files with Landing Aircraft: 323 out of 5376.

# %%
df_landing = pd.concat(dfs)
df_landing
# Out:
#          LATP       LONP  MSQT_1         BAL1         TAS          GS  \
# 0   44.891682 -93.241822     1.0  1006.643045  117.933373  115.007588
# 1   44.888764 -93.234960     1.0   906.643045  115.530863  111.638458
# 2   44.887734 -93.232386     1.0   856.643045  113.021779  110.749442
# 3   44.887502 -93.231929     1.0   846.643045  112.537305  110.196048
# 4   44.887351 -93.231586     1.0   836.643045  111.188473  109.765476
# ..        ...        ...     ...          ...         ...         ...
# 7   44.882928 -93.195317     1.0   786.438823  113.839470  122.158225
# 8   44.882928 -93.195317     1.0   784.438823  113.909336  121.361765
# 9   44.883100 -93.195807     1.0   782.438823  113.571076  120.748203
# 10  44.883100 -93.195807     1.0   780.438823  111.655264  119.874082
# 11  44.883445 -93.196665     1.0   778.438823  109.346476  118.582706
#
#             TH    FLAP       GLS       LOC  ...         CWPC         WS  \
# 0   125.581422  3645.0  0.014040 -0.003136  ...  1782.000000  10.948235
# 1   125.322379  3645.0  0.183690  0.003136  ...  1795.861409   9.932823
# 2   123.876531  3645.0  0.133380  0.003332  ...  1672.000000   6.212059
# 3   124.172654  3645.0  0.136028  0.002001  ...  1718.580098   6.975467
# 4   124.137817  3645.0  0.133199  0.002040  ...  1748.036175   6.994513
# ..         ...     ...       ...       ...  ...          ...        ...
# 7   -59.134194  3645.0  0.069030  0.001176  ...  1467.000000   6.996122
# 8   -58.945564  3645.0  0.069030  0.001176  ...  1581.000000   6.408334
# 9   -58.783896  3645.0  0.307710  0.001568  ...  1665.000000   5.906483
# 10  -58.497770  3645.0  0.307710  0.001568  ...  1296.000000   5.595276
# 11  -58.627378  3645.0  0.083850  0.000588  ...  1365.000000   7.981614
#
#             WD        ALTR     TD_ALTR     TD_LAT     TD_LON      TD_ALT  \
# 0  -159.834434 -536.630359 -104.780302  44.886191 -93.228955  806.643045
# 1  -165.738392 -709.834437 -104.780302  44.886191 -93.228955  806.643045
# 2  -163.252476 -823.996865 -104.780302  44.886191 -93.228955  806.643045
# 3  -166.607074 -688.934215 -104.780302  44.886191 -93.228955  806.643045
# 4  -160.733711 -773.697501 -104.780302  44.886191 -93.228955  806.643045
# ..         ...         ...         ...        ...        ...         ...
# 7   128.635156 -400.249286 -271.354242  44.883445 -93.196665  778.438823
# 8   123.705862 -285.024058 -271.354242  44.883445 -93.196665  778.438823
# 9   119.784757 -376.884980 -271.354242  44.883445 -93.196665  778.438823
# 10  111.880163 -259.560171 -271.354242  44.883445 -93.196665  778.438823
# 11  115.707057 -271.354242 -271.354242  44.883445 -93.196665  778.438823
#
#     heights         DIST
# 0       200  1185.595409
# 1       100   553.902372
# 2        50   320.767080
# 3        40   276.478561
# 4        30   244.578379
# ..      ...          ...
# 7         8   121.006367
# 8         6   121.006367
# 9         4    77.845605
# 10        2    77.845605
# 11        0     0.000000
#
# [3876 rows x 31 columns]

# %%
df_landing.to_csv('processed_data_landing_at_msp.csv',index=False)

# %% [markdown]
# ## Step 2: Feature Selection with Maximum Relevance Minimum Redundancy (MRMR)
# The original 186 parameters are cut down to 26 based on literature review. Then the 26 parameters are further sorted based on Maximum relavance Minimum Redundancy (MRMR).
# Data is first smoothed, and then sliced based on selected heights. The average of each paramters is calculated.
#
# ### Step 2a: Group data by height with ```pandas.groupby```

# %%
grpby = df_landing.groupby(by='heights')
grpby.get_group(0)
# Out:
#          LATP       LONP  MSQT_1        BAL1         TAS          GS  \
# 11  44.886191 -93.228955     1.0  806.643045  103.976395  103.616195
# 11  44.885846 -93.226045     1.0  799.291242  117.358540  119.301601
# 11  44.883786 -93.199606     1.0  822.106482  105.834217   95.831617
# 11  44.885333 -93.226382     1.0  793.020025  112.328895  108.958568
# 11  44.882756 -93.198228     1.0  778.709209  110.752766  104.562259
# ..        ...        ...     ...         ...         ...         ...
# 11  44.892371 -93.216762     1.0  826.453818  111.458923   98.982078
# 11  44.883617 -93.194613     1.0  805.311687  106.816379  107.819248
# 11  44.881725 -93.198044     1.0  815.577007  106.032051  107.148559
# 11  44.877092 -93.204416     1.0  803.589946  111.501855  100.419028
# 11  44.883445 -93.196665     1.0  778.438823  109.346476  118.582706
#
#             TH    FLAP      GLS       LOC  ...    CWPC         WS          WD  \
# 11  123.378983  3645.0  0.27144  0.002744  ...  1667.0   4.278736 -155.074287
# 11  123.410491  3645.0 -0.10959  0.005880  ...  2236.0   6.403527  -64.065263
# 11  -57.981012  3645.0 -0.02184  0.011368  ...  1734.0   8.281502  -54.447144
# 11  121.460417  3645.0 -0.24882  0.004704  ...  2080.0   3.900689  147.137838
# 11  -57.987705  3645.0  0.54210 -0.004900  ...  2210.0   6.968710  -33.283197
# ..         ...     ...      ...       ...  ...     ...        ...         ...
# 11  120.587934  3645.0 -0.01872  0.003724  ...  1488.0  14.964404  114.931008
# 11  -59.479534  3645.0  0.21801  0.001372  ...  1968.0   1.098360 -166.960137
# 11  -54.594218  3645.0  0.38532 -0.001372  ...  2438.0   7.374969   30.142230
# 11  -55.257613  3645.0  0.13455  0.280084  ...  1503.0  12.842577  -31.604227
# 11  -58.627378  3645.0  0.08385  0.000588  ...  1365.0   7.981614  115.707057
#
#           ALTR     TD_ALTR     TD_LAT     TD_LON      TD_ALT  heights  DIST
# 11 -104.780302 -104.780302  44.886191 -93.228955  806.643045        0   0.0
# 11 -177.267211 -177.267211  44.885846 -93.226045  799.291242        0   0.0
# 11  125.745074  125.745074  44.883786 -93.199606  822.106482        0   0.0
# 11 -270.814762 -270.814762  44.885333 -93.226382  793.020025        0   0.0
# 11  -32.735479  -32.735479  44.882756 -93.198228  778.709209        0   0.0
# ..         ...         ...        ...        ...         ...      ...   ...
# 11  -68.149041  -68.149041  44.892371 -93.216762  826.453818        0   0.0
# 11 -166.170628 -166.170628  44.883617 -93.194613  805.311687        0   0.0
# 11  -26.485288  -26.485288  44.881725 -93.198044  815.577007        0   0.0
# 11  138.856011  138.856011  44.877092 -93.204416  803.589946        0   0.0
# 11 -271.354242 -271.354242  44.883445 -93.196665  778.438823        0   0.0
#
# [323 rows x 31 columns]

# %%
grpby.get_group(200).heights
# Out:
# 0    200
# 0    200
# 0    200
# 0    200
# 0    200
#     ...
# 0    200
# 0    200
# 0    200
# 0    200
# 0    200
# Name: heights, Length: 323, dtype: int64

# %% [markdown]
# ### Step 2b: Compute parameter averages at each height

# %%
ave_by_height = pd.DataFrame(columns=df_landing.columns)
for i,g in enumerate(grpby):
    height = g[0]
    df = g[1]
    ave_by_height.loc[i,:] = df.mean()

# %%
ave_by_height
# Out:
#          LATP       LONP    MSQT_1         BAL1         TAS          GS  \
# 0   44.884192 -93.211779  0.996904   804.385162   98.874716  104.063538
# 1   44.884127 -93.211732   0.99705   806.385162  107.530059  106.639878
# 2   44.884118 -93.211736       1.0   808.385162  109.026773   107.63386
# 3   44.884106 -93.211737       1.0   810.385162  110.597024  108.387776
# 4   44.884119 -93.211786       1.0   812.385162  111.971512  109.082017
# 5   44.884114 -93.211799       1.0   814.385162  112.803284  109.617697
# 6   44.884126 -93.211901       1.0   824.385162  115.821616  111.357957
# 7   44.884115 -93.211935       1.0   834.385162  117.522335  112.401629
# 8   44.884104 -93.211944       1.0   844.385162  118.585095  113.139709
# 9   44.884087 -93.211972       1.0   854.385162  119.435397  113.762441
# 10  44.884031 -93.212105       1.0   904.385162  121.977894  115.513472
# 11  44.883946 -93.212434       1.0  1004.385162  123.392287  116.795842
#
#            TH         FLAP       GLS       LOC  ...         CWPC        WS  \
# 0    33.37884  3663.919505  0.006715  0.001765  ...  1832.835913  5.987552
# 1   33.371948   3663.88467  0.023907  0.001431  ...  1848.548725  6.138852
# 2   33.357657  3663.896976  0.006223  0.001095  ...  1863.329123  6.245552
# 3   33.357167  3663.894485  -0.00431  0.001895  ...  1850.152334   6.39752
# 4   33.363979  3663.889485 -0.021477   0.00161  ...   1858.22471  6.702527
# 5   33.365325  3663.891783 -0.028608  0.001991  ...  1861.823818  6.930953
# 6   33.376308  3663.885606 -0.057211  0.000298  ...  1852.309428  7.576133
# 7   33.424848   3663.89505 -0.068371  0.001356  ...  1816.188369  8.035595
# 8    33.45475  3663.876769 -0.050584  0.001114  ...  1828.338907  8.267578
# 9   33.438747  3663.870557 -0.023198    0.0013  ...  1838.654069  8.535319
# 10   33.58066  3663.910628  0.004302  0.001869  ...  1829.698489  9.191626
# 11  33.495927   3663.89207   0.00751  0.002346  ...  1819.306742  9.661476
#
#           WD        ALTR     TD_ALTR     TD_LAT     TD_LON      TD_ALT  \
# 0   9.670039 -142.563363 -142.563363  44.884192 -93.211779  804.385162
# 1   4.442049 -292.490647 -142.563363  44.884192 -93.211779  804.385162
# 2   1.264728 -343.020011 -142.563363  44.884192 -93.211779  804.385162
# 3   0.713573  -405.50305 -142.563363  44.884192 -93.211779  804.385162
# 4   1.933554 -455.366942 -142.563363  44.884192 -93.211779  804.385162
# 5   1.629935 -490.374351 -142.563363  44.884192 -93.211779  804.385162
# 6   1.348635 -608.236475 -142.563363  44.884192 -93.211779  804.385162
# 7   5.862442 -670.548148 -142.563363  44.884192 -93.211779  804.385162
# 8   5.108144 -671.830338 -142.563363  44.884192 -93.211779  804.385162
# 9   2.737421 -691.349528 -142.563363  44.884192 -93.211779  804.385162
# 10 -0.275884 -663.385918 -142.563363  44.884192 -93.211779  804.385162
# 11  -3.07077 -637.342906 -142.563363  44.884192 -93.211779  804.385162
#
#    heights         DIST
# 0      0.0          0.0
# 1      2.0    75.611048
# 2      4.0   108.689308
# 3      6.0   136.416163
# 4      8.0   160.098133
# 5     10.0    180.00225
# 6     20.0   257.156977
# 7     30.0   317.062297
# 8     40.0   369.753088
# 9     50.0   423.456526
# 10   100.0   691.197014
# 11   200.0  1259.803721
#
# [12 rows x 31 columns]

# %% [markdown]
# ### Step 2c: Compute MRMR with Spearman Correlation Relative to Veritical Velocity ```ALTR```

# %%
sele_key_list=['CCPC','CTAC','PTCH','ELEV_1','BLAC','N1_1','GS','TAS','GLS','WS','ROLL',\
               'FPAC','WD','LONP','TH','LATP','DIST','AIL_1','LOC','TRK','BAL1','RUDD','FLAP','ALTR']
ave_by_height = ave_by_height[sele_key_list]

# %%
ave_by_height
# Out:
#            CCPC      CTAC      PTCH    ELEV_1      BLAC       N1_1  \
# 0    1926.73065  0.001563  2.437592  0.110089 -0.039902  34.600852
# 1   2008.324588 -0.002311  1.974665 -0.889584 -0.050227  37.116829
# 2   2039.832899 -0.001895  1.759162 -1.459126  -0.05282  38.587362
# 3   2065.154614 -0.003231  1.525746 -2.014512 -0.054705  40.121825
# 4   2108.657252 -0.003233  1.271863 -2.488021 -0.056525  41.516511
# 5   2127.812796 -0.003563  1.057435 -2.690659 -0.057964  42.748676
# 6   2202.010385 -0.001612  0.137774  -3.95079 -0.061005  47.460409
# 7   2263.670912  0.000628 -0.687212 -4.591668 -0.062207  50.603226
# 8   2286.979909  0.002338 -1.288202 -5.266081 -0.062829  52.461056
# 9    2323.58186  0.000205 -1.735114 -5.509513 -0.063787  53.606588
# 10  2316.260609  0.000522  -2.39839 -5.585112 -0.053109  56.045798
# 11  2318.248761  0.000883  -2.67683 -5.618369 -0.050126  57.258882
#
#             GS         TAS       GLS        WS  ...         TH       LATP  \
# 0   104.063538   98.874716  0.006715  5.987552  ...   33.37884  44.884192
# 1   106.639878  107.530059  0.023907  6.138852  ...  33.371948  44.884127
# 2    107.63386  109.026773  0.006223  6.245552  ...  33.357657  44.884118
# 3   108.387776  110.597024  -0.00431   6.39752  ...  33.357167  44.884106
# 4   109.082017  111.971512 -0.021477  6.702527  ...  33.363979  44.884119
# 5   109.617697  112.803284 -0.028608  6.930953  ...  33.365325  44.884114
# 6   111.357957  115.821616 -0.057211  7.576133  ...  33.376308  44.884126
# 7   112.401629  117.522335 -0.068371  8.035595  ...  33.424848  44.884115
# 8   113.139709  118.585095 -0.050584  8.267578  ...   33.45475  44.884104
# 9   113.762441  119.435397 -0.023198  8.535319  ...  33.438747  44.884087
# 10  115.513472  121.977894  0.004302  9.191626  ...   33.58066  44.884031
# 11  116.795842  123.392287   0.00751  9.661476  ...  33.495927  44.883946
#
#            DIST      AIL_1       LOC        TRK         BAL1      RUDD  \
# 0           0.0  85.077908  0.001765  33.471943   804.385162 -1.797128
# 1     75.611048   84.88423  0.001431  33.471821   806.385162 -1.966797
# 2    108.689308  84.991761  0.001095   33.47203   808.385162 -2.306965
# 3    136.416163  85.062112  0.001895  33.481436   810.385162 -2.098378
# 4    160.098133  85.084116   0.00161  33.494974   812.385162 -1.667993
# 5     180.00225  84.750436  0.001991  33.496004   814.385162 -1.917367
# 6    257.156977  84.808573  0.000298   33.50542   824.385162 -1.776841
# 7    317.062297  85.144737  0.001356  33.504223   834.385162 -1.929116
# 8    369.753088  85.324964  0.001114  33.483321   844.385162 -2.046254
# 9    423.456526  84.684193    0.0013  33.471277   854.385162 -1.846026
# 10   691.197014  85.006264  0.001869  33.502177   904.385162 -1.734528
# 11  1259.803721  84.926634  0.002346  33.402444  1004.385162 -1.600968
#
#            FLAP        ALTR
# 0   3663.919505 -142.563363
# 1    3663.88467 -292.490647
# 2   3663.896976 -343.020011
# 3   3663.894485  -405.50305
# 4   3663.889485 -455.366942
# 5   3663.891783 -490.374351
# 6   3663.885606 -608.236475
# 7    3663.89505 -670.548148
# 8   3663.876769 -671.830338
# 9   3663.870557 -691.349528
# 10  3663.910628 -663.385918
# 11   3663.89207 -637.342906
#
# [12 rows x 24 columns]

# %%
from scipy import stats
def order_features_mrmr(df,output='ALTR',redundancy_weight=0.5):
    selected_order = []
    
    R = np.abs(stats.spearmanr(df.values,axis=0)[0])
    output_idx = df.columns.get_loc(output)
    input_idx = [i for i in range(df.shape[1]) if i != output_idx]
    
    corr_with_output = R[input_idx,output_idx]
    corr_with_inputs = R[[[i] for i in input_idx],input_idx]
    
    idx_best = np.argmax(corr_with_output)
    selected_order.append(idx_best)
    input_idx.remove(idx_best)
    while len(input_idx)!=0:
        with_output = corr_with_output[input_idx]
        with_others = np.array([np.mean(corr_with_inputs[idx,input_idx]) for idx in input_idx])
            
        mrmr_values = with_output-with_others*redundancy_weight
        mrmr_max_idx = np.argmax(mrmr_values)
        best_index=input_idx[mrmr_max_idx]
        
        input_idx.remove(best_index)
        selected_order.append(best_index)
    ordered_features = df.columns[selected_order]
    return ordered_features

# %%
min_redundancy_weight = [0,.25,.5,.75,1] #contribution of minimum redundancy
df_features = pd.DataFrame(np.zeros([len(sele_key_list)-1,len(min_redundancy_weight)]),columns=min_redundancy_weight)
for i,weight in enumerate(min_redundancy_weight):
    ordered_features = order_features_mrmr(ave_by_height,redundancy_weight=weight)
    df_features.iloc[:,i]=ordered_features

# %%
df_insert = pd.DataFrame({key:'ALTR' for key in df_features.columns},index=[0])
df_features = pd.concat([df_insert,df_features]).reset_index(drop = True)
df_features
# Out:
#       0.00    0.25    0.50    0.75    1.00
# 0     ALTR    ALTR    ALTR    ALTR    ALTR
# 1     CCPC    CCPC    CCPC    CCPC    CCPC
# 2     PTCH    PTCH    BLAC    BLAC    BLAC
# 3   ELEV_1  ELEV_1    PTCH    PTCH     GLS
# 4     N1_1    N1_1  ELEV_1  ELEV_1    PTCH
# 5       GS      GS    N1_1    N1_1  ELEV_1
# 6      TAS     TAS      GS      GS    N1_1
# 7       WS      WS     TAS     TAS      GS
# 8     DIST    DIST      WS      WS     TAS
# 9     BAL1    BAL1    DIST    DIST      WS
# 10    FPAC    FPAC    BAL1    BAL1    DIST
# 11    LONP    LONP    FPAC    FPAC    BAL1
# 12    BLAC    BLAC    LONP    LONP    FPAC
# 13    LATP    LATP    LATP    LATP    LONP
# 14      TH      TH      TH      TH    LATP
# 15     GLS     GLS     GLS     GLS      TH
# 16    ROLL    ROLL    ROLL    ROLL    ROLL
# 17    FLAP    FLAP    FLAP    FLAP    FLAP
# 18    CTAC    CTAC    CTAC    CTAC    CTAC
# 19     TRK     TRK     TRK     TRK     TRK
# 20    RUDD    RUDD    RUDD    RUDD    RUDD
# 21     LOC     LOC     LOC     LOC     LOC
# 22      WD      WD      WD      WD      WD
# 23   AIL_1   AIL_1   AIL_1   AIL_1   AIL_1

# %%
df_features.to_csv('ordered_features.csv',index=False)
